# %%
# !pip install PyPDF2
# Out:
# Requirement already satisfied: PyPDF2 in /usr/local/lib/python3.10/dist-packages (3.0.1)

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.33.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.17.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.3.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)

# %% [markdown]
# # **Part - 1 PDF Data Extraction**

# %% [markdown]
# **Importing Libraries**

# %%
import os
import re
import PyPDF2
import string
import nltk
import spacy
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

# Download NLTK resources (if not already downloaded)
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")
nlp = spacy.load("en_core_web_sm")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# **Get List of Folders Containing CVs**

# %%
path = '/content/drive/MyDrive/Resumes'
folder_path = []

dir_list = os.listdir(path)

for _ in dir_list:
  folder_path.append(os.path.join(path, _))

# %% [markdown]
# **Get the file paths of all the CVs**

# %%
pdf_path = []

for i in folder_path:
  for root, dirs, files in os.walk(i):
      for file in files:
          if file.lower().endswith(".pdf"):
            file_path = os.path.join(root, file)
            pdf_path.append(file_path)

# %%
len(pdf_path)
# Out:
# 2484

# %% [markdown]
# **Extracting Category(Job Role) from the PDF and Preprocessing it**

# %%
category_list = []

for path in pdf_path:
# Open the PDF file
  with open(path, 'rb') as pdf_file:
      pdf_reader = PyPDF2.PdfReader(pdf_file)

      # Extract text from the PDF
      pdf_text = ''
      for page in pdf_reader.pages:
          pdf_text += page.extract_text()

      # Define regular expressions for matching job category, skills, and education
      category_pattern = r'^[^\n]*'

      # Extract category, skills, and education using regex
      category_match = re.search(category_pattern, pdf_text, re.DOTALL)

      # Extracted information
      category = category_match.group(0).strip() if category_match else "None"

      category_list.append(category)

# %%
category_preprocessed = []

def preprocess_text(text):
    # Remove URLs
    text = re.sub(r'http\S+', '', text)

    # Remove email addresses
    text = re.sub(r'\S+@\S+', '', text)

    # Remove special characters and digits
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\d+', '', text)

    # Convert text to lowercase
    text = text.lower()

    # Tokenize using SpaCy
    doc = nlp(text)
    tokens = [token.text for token in doc]

    # Remove stopwords using NLTK and SpaCy
    stopwords_nltk = set(nltk.corpus.stopwords.words("english"))
    stopwords_spacy = nlp.Defaults.stop_words
    tokens = [token for token in tokens if token not in stopwords_nltk]
    tokens = [token for token in tokens if token not in stopwords_spacy]

    # Perform stemming using NLTK
    stemmer = nltk.PorterStemmer()
    tokens = [stemmer.stem(token) for token in tokens]

    # Perform lemmatization using SpaCy
    tokens = [token.lemma_ for token in doc]

    # Join the preprocessed words back into a string
    preprocessed_text = " ".join(tokens)
    return preprocessed_text

# Example usage
for text in category_list:
  preprocessed_tokens = preprocess_text(text)
  category_preprocessed.append(preprocessed_tokens)

# %%
category_preprocessed
# Out:
# ['fitness attendant',
#  'general manager',
#  'manager   fitness instructor',
#  'concierge',
#  'fitness instructor',
#  'group fitness coordinator',
#  'mover',
#  'sale associate',
#  'rnrn team lead',
#  'fitness director',
#  'group fitness instructor',
#  'recreation   sport coordinator',
#  'receptionist and veterinary technician',
#  'intern',
#  'yoga instructor',
#  'flight attendant',
#  'senior exercise specialist   sport and recreation coordinator',
#  'vice president',
#  'o',
#  'athletic director coach pe teacher',
#  'certify master personal trainer',
#  'medical scribe',
#  'social medium agent',
#  'operation associate',
#  'bartender on call',
#  'fitness staff',
#  'physical therapy aide',
#  'aba therapist',
#  'avid tutor',
#  'yoga instructor',
#  'advocare distributor',
#  'intern',
#  'group exercise fitness instructor',
#  'administrative office assistant',
#  'fitness consultant',
#  'sale associate',
#  'professional fitness trainer group instructor',
#  'owneroperator',
#  'customer care representative',
#  'guest lecturer',
#  'rehabilitation specialist   massage therapist',
#  'social medium producer',
#  'mechanical design engineer intern',
#  'intern',
#  'emergency department physician',
#  'assistant generaloperation manager',
#  'clinical study coordinator ii',
#  'adventure run coordinator',
#  'personal trainer',
#  'program managerbusiness analyst',
#  'rd new product development technician',
#  'human resource manager',
#  'fitness traineerecreation management intern',
#  'group fitness instructor',
#  'certify fitness trainer',
#  'procurement analyst',
#  'executive assistantoffice manager',
#  'office manager',
#  'operation manager',
#  'owneroperator',
#  'online coach personal training',
#  'branch logistic manager',
#  'store manager',
#  'account executive',
#  'fitness specialist',
#  'register nurse supervisor',
#  'accommodation service executive ll',
#  'digital marketing lead',
#  'night warehouse selector',
#  'senior implementation manager',
#  'product specialist',
#  'manager',
#  'fitness coordinator',
#  'group fitness instructor',
#  'membership coordinator',
#  'health coach',
#  'team member   pricer',
#  'service representative',
#  'personal trainer',
#  'directorpresident   minturn fitness center',
#  'general manager',
#  'sale associate',
#  'director of operation',
#  'senior sale management consultant',
#  'cashier',
#  'certify personal trainer and group fitness instructor',
#  'general managerfitness director',
#  'general manager',
#  'cashier',
#  'branch manager',
#  'fitness director',
#  'personal trainer group fitness instructor',
#  'wellness director',
#  'operation manager',
#  'floaterteacher',
#  'customer care representative',
#  'care coordinator',
#  'fitness instructor',
#  'veterinary assistant',
#  'interim membership director',
#  'program manager',
#  'group fitness instructor',
#  'fitness instructor',
#  'equipment operator and fitness leader',
#  'customer service representactive',
#  'fitness trainer',
#  'server',
#  'sale associatecashier',
#  'kid club attendant',
#  'receive manager',
#  'group fitness instructor',
#  'territory sale consultant',
#  'night service representative',
#  'head girl basketball coach',
#  'senior medical recruiter',
#  'program manager',
#  'child center asst dept head',
#  'it management',
#  'information technology manager',
#  'information technology coordinator',
#  'information technology specialist',
#  'branch chief information technology specialist',
#  'work rf system engineer',
#  'information technology manager',
#  'information technology technician I',
#  'director of information technology',
#  'aspnet web developer',
#  'practice manager',
#  'lead information technology support specialist',
#  'manager   information technology and building automation system',
#  'director of information technology',
#  'information technology manager',
#  'production associate',
#  'information technology it specialist',
#  'information technology specialist',
#  'objective',
#  'director of information technology',
#  'director of information technology',
#  'information technology project manager system analysis sysanalsy gs',
#  'project manager',
#  'information technology manageranalyst',
#  'database programmeranalyst net developer',
#  'information technology specialist',
#  'senior vicepresident and chief information officer',
#  'director of information technology',
#  'information technology senior manager',
#  'information technology manager   network engineer',
#  'master datum manager',
#  'information technology specialist information security officer',
#  'information technology manager',
#  'information technology student',
#  'information technology analyst',
#  'information technology specialist',
#  'senior information technology manager',
#  'senior vice president of global information technology',
#  'information technology auditor',
#  'epic information technology specialist',
#  'senior vp   information technology',
#  'director of information technology',
#  'information technology and aws admin intern',
#  'head information technology and information center',
#  'director of information technology chief technology officer',
#  'information technology specialist iii drupal dev',
#  'information technology specialist',
#  'information technology support specialistnetwork specialist pc technician it consultant',
#  'information technology internship',
#  'information technology specialist',
#  'information technology specialist gs',
#  'director of information technology and analytic',
#  'director of information technology',
#  'administrator of information technology',
#  'information technology instructor',
#  'vice president information technology infrastructure operation',
#  'staff assistant',
#  'information technology director',
#  'information technology specialist',
#  'information technology specialist',
#  'information technology specialist infosec',
#  'it technology specialist',
#  'customer service representative',
#  'information technology specialist',
#  'information technology specialist',
#  'training manager',
#  'information technology certify technician',
#  'experience information technology manager',
#  'information technology specialistsystem analysis',
#  'system administrator',
#  'database programmeranalyst net developer',
#  'corporate project manager',
#  'it director',
#  'information technology administrator',
#  'director information technology',
#  'information technology specialist',
#  'support   network service intern',
#  'information technology project manager',
#  'it manager',
#  'vice president information technology   software engineering',
#  'director of information technology',
#  'manager information technology project management office',
#  'information technology supervisor',
#  'senior director information technology',
#  'consultant',
#  'information technology specialist web gs',
#  'information technology coordinator',
#  'adjunct instructor',
#  'business system analyst I',
#  'information technology specialist',
#  'assistant football coach',
#  'it support technician',
#  'vp of information technology',
#  'information technology consultant',
#  'staff pharmacist',
#  'assistant information technology it director',
#  'information technology',
#  'information technology bureau deputy director',
#  'amc computer specialist and intern',
#  'information technology specialistdiscountpcfix',
#  'information technology manager',
#  'information technology consultant',
#  'vice president information technology',
#  'freelance it consultant',
#  'information technology intern',
#  'subject matter expert information technology assistant',
#  'information technology intern test automation engineer',
#  'information technology provision technician',
#  'information technology help desk specialist',
#  'information technology specialist',
#  'operation research analyst',
#  'information technology consultant manage member',
#  'it manager',
#  'information technology specialist I',
#  'information technology manager',
#  'information technology specialist',
#  'christopher towne',
#  'director of information technology',
#  'administrative assistant director human resource manager production manager engineering',
#  'information technology coordinator',
#  'hr benefitsleave coordinator',
#  'hr manager',
#  'hr personnel assistant',
#  'hr employee relation specialist',
#  'hr generalist',
#  'hr generalist',
#  'hr specialist',
#  'hr representative',
#  'hr coordinator',
#  'hr senior specialist',
#  'hr director',
#  'hr managergeneralist',
#  'hr generalist',
#  'hr manager',
#  'hr service representative',
#  'hr consulting',
#  'hr specialist',
#  'regional hr deputy manager',
#  'hr manager',
#  'hr assistant',
#  'hr coordinator',
#  'hr coordinator',
#  'sr hr generalist',
#  'assistant manager   hr',
#  'hr manager',
#  'hr share service analyst',
#  'hr administratormarkete associate hr administrator',
#  'volunteer hr ivolunteer',
#  'hr manager',
#  'hr consulting',
#  'hr directoradministrator',
#  'hr generalist',
#  'hr associate',
#  'hr specialist',
#  'senior hr manager',
#  'hr business partner ii',
#  'hr director',
#  'recruiting and hr manager',
#  'hr intern',
#  'hr generalist',
#  'hr assistant intern',
#  'summary',
#  'hr coordinator',
#  'hr specialist information system',
#  'executive assistant hr',
#  'hr consultant',
#  'field hr associate',
#  'hr specialist we hr operation',
#  'designation hr assistant',
#  'global hr manager',
#  'hr manager',
#  'hr contact center specialist',
#  'hr assistant iii',
#  'hr partner',
#  'hr director',
#  'hr generalist',
#  'hr coordinator',
#  'senior hr manager hr business partner',
#  'hr consultant',
#  'hr manager',
#  'regional hr manager',
#  'sr hr consultant',
#  'territory hr manager',
#  'hr coordinator',
#  'directv hr recruiter administration',
#  'hr specialist',
#  'hr specialist',
#  'hr specialist horizontal engineer',
#  'hr administrator',
#  'hr assistant',
#  'hr payroll accounting representative',
#  'hr associate',
#  'hr generalist',
#  'hr generalist',
#  'hr customer service representative',
#  'hr assistant',
#  'director of hr',
#  'regional hr business partner',
#  'hr associate mobilization coordinator',
#  'hr representative',
#  'hr assistant',
#  'hr director',
#  'hr clerk',
#  'hr clerk',
#  'hr generalist',
#  'hr managerbusiness partner',
#  'hr manager',
#  'hr business partner',
#  'hr manager',
#  'senior hr business partner',
#  'hr assistantpayroll',
#  'hr   safety manager',
#  'hr executive',
#  'hr coordinator',
#  'hr volunteer asst manager',
#  'hr generalist',
#  'hr professional',
#  'hr generalist',
#  'hr coordinator',
#  'hr consultant',
#  'hr generalistrecruiter',
#  'hr executive',
#  'hr assistant',
#  'senior hr',
#  'general hr assistantoffice assistant',
#  'hr specialist',
#  'hr generalist',
#  'hr manager',
#  'hr analyst',
#  'hr intern',
#  'lead teacher',
#  'substitute teacher',
#  'classroom teacher',
#  'biology teacher',
#  'teacher',
#  'master teacher',
#  'teacher',
#  'guest teacher',
#  'teacher',
#  'substitute teacher',
#  'teacher',
#  'teacher',
#  'teacher',
#  'assistant teacher',
#  'kindergarten teacher',
#  'teacher',
#  'teacher',
#  'associate teacher',
#  'teacher',
#  'assistant teacher',
#  'teacher',
#  'teacher',
#  'preschool teacher',
#  'lead teacher',
#  'kindergarten teacher',
#  'teacher',
#  'teacher and read teacher',
#  'teacher',
#  'assistant teacher',
#  'art teacher',
#  'inclusion teacher',
#  'homebound teacher',
#  'directorpreschool teacher',
#  'preschool teacher',
#  'teacher',
#  'teacher',
#  'assistant teacher',
#  'english teacher',
#  'teacher',
#  'teacher',
#  'teacher',
#  'teacher',
#  'bi teacher',
#  'teacher',
#  'lead teacher',
#  'teacher',
#  'substitute teacher',
#  'teacher',
#  'kimberly fisheli',
#  'assistant teacher',
#  'teacher',
#  'engineering teacher',
#  'teacher',
#  'teacher',
#  'teacher assistant',
#  'teacher',
#  'teacher',
#  'teacher',
#  'history teacher',
#  'teacher',
#  'teacher',
#  'spanish teacher',
#  'lead teacher',
#  'teacher',
#  'teacher',
#  'science teacher',
#  'preschool teacher',
#  'teacher',
#  'teacher',
#  'teacher',
#  'teacher',
#  'teacher',
#  'substitute teacher',
#  'teacher',
#  'teacher',
#  'teacher',
#  'teacher',
#  'teacher',
#  'preschool teacher',
#  'guest teacher',
#  'english teacher',
#  'math teacher',
#  'teacher',
#  'teacher',
#  'teacher',
#  'marilyn hunter',
#  'substitute teacher',
#  'tw',
#  'teacher',
#  'classroom teacher',
#  'teacher',
#  'preservice teacher',
#  'teacher assistant',
#  'substitute teacher',
#  'teacher',
#  'history teacher',
#  'math teacher math intervention teacher',
#  'teacher',
#  'read teacher',
#  'teacher',
#  'kpandipou koffi',
#  'teacher',
#  'behavioral healthcare help line and psychiatric emergency team supervisor',
#  'aircraft hydraulic journyman',
#  'pharmaceutical sale representative women healthcare specialist',
#  'sleep technologist rpsgt',
#  'chief executive officer',
#  'director new product research and rd liaison global oral healthcare rd consumer',
#  'healthcare recruiter',
#  'director of national sale us healthcare',
#  'corporate administrator',
#  'medical support assistant oa gs step',
#  'senior director of business operation   healthcare',
#  'emergency room admit specialistquality assurance',
#  'facility manager',
#  'nc air guard health service manager',
#  'personal healthcare assistant',
#  'occupational health nurse coordinator',
#  'medical record technician',
#  'project manager',
#  'register nurse',
#  'certify personal trainer',
#  'account executive',
#  'field base nurse chart reviewer   healthcare informatic',
#  'teacher assistant',
#  'health information specialist',
#  'key account manager',
#  'director clinical research operation   medical science liaison',
#  'license united healthcare insurance sale agent',
#  'corporate regional recruiter',
#  'supervisor',
#  'professional healthcare representative',
#  'cna in skilled healthcare',
#  'senior managerspecialist leader healthcare',
#  'highly accomplished healthcare analyst',
#  'marketer   administrator',
#  'director compound sale specialist',
#  'electronic health record optimization specialist',
#  'technical it healthcare consultant',
#  'system administratorassistant supervisor',
#  'office managermanage director',
#  'professional healthcare representative',
#  'claim service specialist',
#  'healthcare administrator',
#  'healthcare clinical analyst',
#  'director of application',
#  'healthcare administratoroperational and staff reorg',
#  'healthcare',
#  'team leader machine operator',
#  'healthcare effectiveness and information set coordinator hedi',
#  'healthcare consulting project associate',
#  'certify nursing assistant',
#  'senior analyst   business intelligence and analytic   healthcare',
#  'clinical research coordinator mentor   quality assurance',
#  'license united healthcare insurance sale agent',
#  'health system analyst',
#  'senior specialty sale representative',
#  'recruiter tax exempt market',
#  'project coordinator',
#  'healthcare administration intern',
#  'hospital   physician billing specialist',
#  'home healthcare technician',
#  'engineer',
#  'operation manager',
#  'senior analyst datum quality   governance',
#  'field nurse',
#  'healthcare documentation service delivery manager',
#  'commission specialist',
#  'sr project manager',
#  'license practical nurse stepdown unit',
#  'audit and recovery specialist',
#  'national administrator population health and associate director visit clinical practice',
#  'executive director',
#  'communicable disease specialist',
#  'staff coordinator',
#  'healthcare provider',
#  'preventative healthcare intern',
#  'enumerator',
#  'practice manager',
#  'administrative assistant',
#  'administrator',
#  'regional recruiter',
#  'owner',
#  'cashier',
#  'advisor',
#  'rachael lobdell',
#  'healthcare consultant',
#  'business office manager',
#  'admin operating room administrative coordinator',
#  'healthcare associate',
#  'surgical clinical reviewer',
#  'dining service coordinator',
#  'occupational therapist',
#  'administrative assistant',
#  'healthcare effectiveness datum and information set coordinator hedi',
#  'digital marketing specialist',
#  'healthcare instructional assistant',
#  'I',
#  'medical support assistant',
#  'license healthcare communicator',
#  'healthcare recruiter',
#  'register nurse',
#  'r',
#  'vice presidentbusiness banking sale manager and healthcare specialty banker',
#  'patient care technician',
#  'healthcare consultant',
#  'g',
#  'staff manager',
#  'customer service representative',
#  'hire managerrecruite manager',
#  'healthcare consultant',
#  'manager field',
#  'pa medium group',
#  'I',
#  'impact',
#  'director quality improvement network facilitation',
#  'platform architect healthcare incubation lab hil',
#  'engineering lab technician',
#  'senior engineering manager',
#  'senior engineering program manager',
#  'engineer technician',
#  'director of engineering',
#  'engineering service manager',
#  'engineering operation director',
#  'engineering manager',
#  'equipment engineering technician',
#  'mechanical engineering intern',
#  'regional engineering manager',
#  'engineering and quality technician',
#  'engineering intern',
#  'software engineering manager',
#  'qa engineering team lead',
#  'engineering intern',
#  'electrical engineering lab technician',
#  'engineer technician v',
#  'biomedical engineering technician ii',
#  'process engineering technician iii',
#  'engineering assistant',
#  'engineering assistant',
#  'engineer technician',
#  'selfsustaine engineering technician',
#  'engineering technician iii',
#  'corporate processsystem engineering manager',
#  'engineering associate',
#  'engineering manager',
#  'engineering project manager iii',
#  'clinical engineering manager',
#  'project administrator engineering',
#  'industrial engineering intern',
#  'engineering assistant',
#  'mechanical engineering intern',
#  'engineering managerquality manager',
#  'multiskille engineering manager',
#  'engineering intern',
#  'engineering supervisor',
#  'engineering planning manager',
#  'engineering supervisor',
#  'engineering business unit leader',
#  'engineer technician field service',
#  'engineering project manager',
#  'engineering assistant',
#  'corporate engineering support technician',
#  'engineering manager',
#  'software engineering team lead',
#  'engineering technician ii',
#  'engineering intern',
#  'engineering lab technician',
#  'engineer technician',
#  'engineering specialist',
#  'engineer technician',
#  'engineering intern',
#  'engineer technician',
#  'engineering manager',
#  'facility engineering manager',
#  'engineering technologist',
#  'thermal engineering intern',
#  'engineering manager',
#  'software engineering manager',
#  'engineer technician',
#  'engineering supervisor',
#  'engineering manager',
#  'software engineering manager',
#  'engineering specialist',
#  'engineering team lead',
#  'engineer technician',
#  'engineering tech',
#  'engineering intern',
#  'qa engineering manager',
#  'engineering assistant',
#  'engineering office clerk',
#  'industrial engineering intern',
#  'manager engineering manufacturing system engineering manager',
#  'manager quality engineering',
#  'mechanical engineering tutor',
#  'software engineering analyst',
#  'construction engineering supervisor',
#  'software engineering manager',
#  'process engineering intern',
#  'engineering project manager',
#  'engineering project manager',
#  'engineer managersenior mechanical designer',
#  'engineering manager',
#  'engineering aide',
#  'engineering intern',
#  'engineering supervisor',
#  'engineer technician',
#  'director of engineering',
#  'engineering system installer',
#  'engineering coordinator',
#  'lighting field engineering technician',
#  'director of engineering',
#  'support engineering manager',
#  'engineering intern',
#  'system engineering manager',
#  'software engineering manager',
#  'engineer technician',
#  'engineering manager',
#  '  industrial engineering manager',
#  'mechanical engineering intern',
#  'site engineering',
#  'mineralogy engineering intern',
#  'engineering manager',
#  'engineering intern',
#  's',
#  'chemical engineering intern',
#  'engineering intern',
#  'engineering officer',
#  'test engineering',
#  'mechanical design engineering intern',
#  'engineering manager',
#  'software engineering manager',
#  'engineering manager',
#  'director of engineering',
#  'senior manufacturing engineering',
#  'maintenance engineering coop',
#  'sr leave of administrative specialist',
#  'medium activity specialist',
#  'digital medium sale consultant',
#  'digital medium buyer',
#  'medium administrator',
#  'digital marketing intern',
#  'monitor tech',
#  'sprint isp management to the vendor',
#  'social medium manager',
#  'director',
#  'contract senior associate medium planner at sapientnitro',
#  'digital advertising consultant',
#  'social medium marketing manager',
#  'substitute teacher',
#  'digital producer',
#  'digital medium intern',
#  'digital marketing manager',
#  'digital marketing associate',
#  'interim senior digital marketing strategy manager',
#  'digital medium consultant',
#  'operation technician',
#  'live functional administratorsupervisor of it help desk',
#  'lead artist',
#  'digital strategy consultant',
#  'social engage sale',
#  'medium   advertising coordinator',
#  'ownerpresident',
#  'director of digital transformation',
#  'director of new business development',
#  'director medium strategy',
#  'videographer',
#  'software engineer',
#  'digital marketing coordinator',
#  'social medium coordinator',
#  'programmatic medium supervisor',
#  'senior digital marketing specialist',
#  'digital marketing manager',
#  'vp digital medium service and content distribution',
#  'social medium coordinator',
#  'digital marketing account manager',
#  'global sr manager pay medium',
#  'digital communication specialist',
#  'chief system architect svp system integration',
#  'digital marketing manager',
#  'digital marketing specialist',
#  'social medium analyst',
#  'exec director of sale consultant strategist',
#  'medium support specialist',
#  'senior director product management',
#  'digital project manager',
#  'senior digital producermultimedia specialist',
#  'director it client service film   operation and technical service west coast',
#  'digital premedia specialist',
#  'digital project manager',
#  'implementation consultant',
#  'digital merchandising analyst',
#  'editorial assistant',
#  'vicepresident datum and marketing technology',
#  'sale representative',
#  'vice president director of client service digital',
#  'medium service coordinator',
#  'digital production manager',
#  'social medium evaluator',
#  'coceo the jillofalltrade',
#  'business development   digital medium marketing specialist',
#  'technical project manager',
#  'digital content editor',
#  'communication specialist',
#  'digital marketing manager',
#  'digital medium producer',
#  'jr publisher manager',
#  'global digital servicing   digital onboarding coordinator contractor',
#  'chief digital officer',
#  'pay medium specialist',
#  'digital client lead',
#  'director global digital marketing',
#  'public relation intern',
#  'senior digital marketing analyst',
#  'senior marketing manager',
#  'digital strategy manager',
#  'sr digital analytic manager',
#  'media specialist ii',
#  'director of donor relation',
#  'social medium content creator',
#  'it   medium administrator',
#  'social medium coordinator',
#  'digital I research intern',
#  'digital consultant',
#  'digital advertising operation intern',
#  'senior manager digital marketing',
#  'digital marketing specialist',
#  'director of digital innovation and strategy',
#  'director of social medium marketing',
#  'digital medium manager',
#  'medium weather forecaster',
#  'digital marketing director',
#  'finance director',
#  'director of finance',
#  'vice president corporate finance',
#  'director finance and fpa',
#  'director of finance',
#  'finance manager',
#  'finance',
#  'finance coordinator',
#  'finance manager',
#  'finance manager',
#  'finance manager',
#  'finance manager operation manager',
#  'director of finance',
#  'finance and operation manager',
#  'senior manager national sale finance',
#  'director of finance',
#  'finance officer',
#  'senior executive   finance',
#  'finance director',
#  'finance manager',
#  'student finance consultant',
#  'phd candidate in finance',
#  'finance manager',
#  'finance manager   plant controller',
#  'finance specialist',
#  'finance director',
#  'finance officer',
#  'finance assistant',
#  'finance officer',
#  'finance and operation manager',
#  'assistant director of finance',
#  'director of finance',
#  'finance manager',
#  'operation and finance manager',
#  'contract and finance officer',
#  'finance   admin manager',
#  'human resource finance analyst',
#  'finance and operation manager',
#  'finance manager',
#  'finance director',
#  'dealership finance manager',
#  'programme finance associate',
#  'finance analyst',
#  'finance specialist',
#  'vp finance   ist',
#  'director finance',
#  'senior accountant   finance controller',
#  'special finance manager',
#  'finance accountant',
#  'finance coordinator',
#  'director of finance',
#  'finance manager',
#  'director of finance',
#  'finance manager',
#  'finance consultant',
#  'operation finance director',
#  'global finance accountant',
#  'finance manager finance manager',
#  'budget finance specialist senior',
#  'act finance manager',
#  'manager of finance',
#  'finance manager',
#  'finance controller',
#  'head of account and finance',
#  'finance manager',
#  'finance customer care rep lead',
#  'director finance project',
#  'finance director',
#  'finance manager',
#  'finance officer',
#  'finance specialist',
#  'finance analyst',
#  'finance specialist',
#  'finance assistant',
#  'director of finance',
#  'finance officer',
#  'finance manager',
#  'secretary   finance division',
#  'finance and accounting specialist',
#  'finance business partner',
#  'senior finance manager',
#  'sale   finance manager',
#  'finance operation supervisor manager',
#  'senior student finance specialist',
#  'finance and sale consultant',
#  'finance supervisor',
#  'senior director of finance',
#  'finance director',
#  'finance manager',
#  'finance manager',
#  'an account cum finance manager',
#  'finance manager',
#  'corporate director of finance',
#  'finance manager',
#  'finance project coordinator',
#  'finance business partner',
#  'director finance operation',
#  'finance assistant',
#  'finance controller',
#  'avp finance',
#  'finance office associate',
#  'finance director',
#  'manager finance',
#  'finance manager',
#  'finance director and treasurer',
#  'finance manager',
#  'director of finance',
#  'finance   office manager',
#  'finance manager',
#  'trade finance officer',
#  'finance manager',
#  'senior finance assistant',
#  'manager of finance',
#  'sr finance manager',
#  'finance',
#  'finance manager',
#  'director of finance',
#  'vp of finance',
#  'sale associate',
#  'sale coordinator',
#  'sale associate',
#  'sale associate',
#  'sale executive',
#  'sale',
#  'merchandiser sale',
#  'sale manager',
#  'sale associate',
#  'sale representative',
#  'sale associate',
#  'sale associatecashier',
#  'senior sale assistant sale support',
#  'sale associate',
#  'sale',
#  'sale associate',
#  'camryn',
#  'sale',
#  'sale consultant',
#  'sale associate',
#  'sale associate',
#  'center sale',
#  'sale specialist',
#  'sale associate',
#  'z',
#  'sale associate',
#  'sale',
#  'sale manager',
#  'sale',
#  'sale',
#  'sale rep',
#  'sale associate',
#  'sale associate',
#  'sale',
#  'sale advisor',
#  'sale',
#  'sale associate',
#  'sale team',
#  'sale representative',
#  'sale',
#  'sale representative',
#  'sale',
#  'sale coordinator',
#  'sale representative sale management',
#  'sale associate',
#  'sale',
#  'sale associate',
#  'sale',
#  'sale manager',
#  'sale',
#  'sale manager',
#  'sale associate',
#  'sale associate',
#  'sale',
#  'sale associate',
#  'sale manager territory sale manager',
#  'sale associate',
#  'sale associate',
#  'sale engineer',
#  'sale associategolf sale associate',
#  'sale associate',
#  'db sale',
#  'sale',
#  'outbound sale',
#  'pmcpsm sale manager sale associate',
#  'sale associate',
#  'sale associate',
#  'sale',
#  'sale representativepsr',
#  'sale associate',
#  'sale associate',
#  'sale',
#  'sale',
#  'sale support',
#  'sale',
#  'sale associate',
#  'sale',
#  'sale',
#  'sale clerk',
#  'sale associate',
#  'sale associte',
#  'sale associate',
#  'sale associate',
#  'sale representative',
#  'sale representative',
#  'sale director',
#  'sale',
#  'sale associate',
#  'sale associate',
#  'sale clerk',
#  'sale',
#  'sale consultant',
#  'sale',
#  'sale associate',
#  'timeshare sale',
#  'sale engineer',
#  'sale associate',
#  'sale associate',
#  'sale',
#  'sale coordinator',
#  'sale representative',
#  'sale manager',
#  'sale associate',
#  'sale associatemerchandiser',
#  ...]

# %% [markdown]
# **Extracting Skills from the PDF and Preprocessing it**

# %%
skills_list = []

for path in pdf_path:
# Open the PDF file
  with open(path, 'rb') as pdf_file:
      pdf_reader = PyPDF2.PdfReader(pdf_file)

      # Extract text from the PDF
      pdf_text = ''
      for page in pdf_reader.pages:
          pdf_text += page.extract_text()

      # Define regular expressions for matching job category, skills, and education
      skills_pattern = r'Skills(?:\n|.)+?(?=\n|$)'

      # Extract category, skills, and education using regex
      skills_match = re.search(skills_pattern, pdf_text, re.DOTALL)

      # Extracted information
      skills = skills_match.group(0).strip().replace("Skills\n", "") if skills_match else "None"

      skills_list.append(skills)

# %%
skills_preprocessed = []

def preprocess_text(text):
    # Remove URLs
    text = re.sub(r'http\S+', '', text)

    # Remove email addresses
    text = re.sub(r'\S+@\S+', '', text)

    # Remove special characters and digits
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\d+', '', text)

    # Convert text to lowercase
    text = text.lower()

    # Tokenize using SpaCy
    doc = nlp(text)
    tokens = [token.text for token in doc]

    # Remove stopwords using NLTK and SpaCy
    stopwords_nltk = set(nltk.corpus.stopwords.words("english"))
    stopwords_spacy = nlp.Defaults.stop_words
    tokens = [token for token in tokens if token not in stopwords_nltk]
    tokens = [token for token in tokens if token not in stopwords_spacy]

    # Perform stemming using NLTK
    stemmer = nltk.PorterStemmer()
    tokens = [stemmer.stem(token) for token in tokens]

    # Perform lemmatization using SpaCy
    tokens = [token.lemma_ for token in doc]

    # Join the preprocessed words back into a string
    preprocessed_text = " ".join(tokens)
    return preprocessed_text

# Example usage
for input_text in skills_list:
  preprocessed_tokens = preprocess_text(input_text)
  skills_preprocessed.append(preprocessed_tokens)

# %%
skills_preprocessed
# Out:
# ['none',
#  'acquisition advertising budgeting',
#  'balance client fast safety sale statistic',
#  'patientfocuse care',
#  'sale management',
#  'ad cpr first aid guardian health education presentation relationship building seminar staff',
#  'forklift operator hand truck inventory machinery building material read and interpret drawing safety service time management',
#  'skill   ability management punctual',
#  'asc qa emr pharmacy infection control metric risk management satisfaction staff trading training auditing instrumentation',
#  'bill blood pressure brochure communication skill client email goal set promote health leadership director marketing market',
#  'plan',
#  'microsoft office program',
#  'arap administrative billing system business process cpr',
#  'benefit billing contract cpr certify credit client first aid inventory exchange packaging paint programming progress quality',
#  'program development and implementation',
#  'investigation financial audit digital evidence surveillance undercover fraud website mine social network cell phone',
#  'agile balance budgeting business strategy cad interpersonal communication skill consultation contract clientele client client database',
#  'skill soft skill',
#  'leadership development trainingâ',
#  'administrative management creative lesson plan curriculum development goal setting and implementationâ   athletic program',
#  'adobe photoshop balance conference client client instruct marketing excel microsoft word strong organizational skill program',
#  'skill proficient in data base management entry level',
#  'highlight',
#  'license notary',
#  'phone call answer',
#  'fast learner',
#  'accounting account payable abc budget contract cpr certify client client excellent customer service customer service training',
#  'conversational in american sign language',
#  'computer skill include microsoft office',
#  'communication',
#  'organizational skill',
#  'client interaction forklift health and safety standard excel office powerpoint microsoft word recruit safety website',
#  'accountability',
#  'academic schedule appointment benefit blood pressure cpr critical thinking customer service staff train special event first aid lesson',
#  'skill',
#  'cash handling',
#  'professional fitness trainer nesta trx certify trainer kettlebell certify trainer office management accounting scheduling',
#  'account management account payablereceivable budgeting business development client relation cold call computer proficient',
#  'account reconciliation',
#  'basic council english instructor language speaker quality read safety spanish supervise',
#  'microsoft office powerpoint word excel',
#  'extremely productive in a high volume high stress environment',
#  'handson experience autocad autodesk inventor pro engineer creo microstation solidworks catia v matlab ansys',
#  'exercise science online coach good teaching and instructional ability cpr and first aid macro count corporate wellness assessment',
#  'none',
#  'staff training',
#  'skill for the healthcare professional course',
#  'have experience work on multiple different pos system microsoft excel and other organization site use for scheduling â also very',
#  'client train customer service operation receptionist retail sale sale account management and sale bookkeepe cash cash',
#  'administrative leadership analytical s',
#  'organize and recording datum into microsoft word and excel',
#  'equal opportunity',
#  'excel intermediate microsoft word intermediate powerpoint intermediate',
#  'accounting account payable account receivable administrative function audit billing bookkeeping book budgeting business',
#  'budget coach counseling creativity credit customer service decision make staff training facility maintenance instruction marketing plan',
#  'business intelligence commodity client client financial insurance leadership logistic market work monitor negotiation enterprise',
#  'account payable act administrative skill adobe advertise analytical skill scheduling appointment attention to detail budget coaching',
#  'askronosanososcerner',
#  'human resource   year microsoft office   year community outreach   year community relation   year sale   year',
#  'skillssale   accountmanagement',
#  'sell coaching motivate present write customer relation fitness training professional speaking radio seminar tv organizing tech',
#  'staff development',
#  'bill oral communication negotiate contract client customer service english general manager hire hr inventory korean team leader',
#  'none',
#  'computer literate â excel power point word mind bodyâ',
#  'cna client client client interaction internet explorer mechanical medication administration microsoft excel microsoft office microsoft',
#  'customer service supervisiondecision make dependable staff training and development problem solver public relationsdynamic team player',
#  'digital advertising marketing outside sale retail sale',
#  'customer satisfaction',
#  'computer proficient salesforcecom advanced interpersonal communication skill teacher and mentor project management adaptable and',
#  'microsoft office word excel outlook and powerpoint great organizational skill selfstarter excellent problem solveradditional information',
#  'excellent work knowledge of computer hardware and technology in general proficiency with microsoft windows and office application',
#  'skill   competency',
#  'afaa group exercise',
#  'reliable and dependable',
#  'skill to transform your conversation for the council on renal nutrition of new',
#  'accounting account receivable budget management budget business administration contract credit customer service staff training',
#  'bank cpr fluent in english financial inventory excel microsoft office powerpoint word microsoft word work pos retail spanish',
#  'apt consultant client client general manager instruction inventory meeting payroll policy progress purchase quality risk management',
#  'highlevel strategic alliance skill include but not limit to network collaboration sponsorship and partnership',
#  'budget conflict resolution cpr customer service delivery employee training first aid form health promotion hr leadership',
#  'excellence and experience in customer service eager and fast learner honest advanced problemsolve exceptional organizational skill',
#  'account management account receivables administrative support subordinate counseling computer proficiency customer service',
#  'work history',
#  'account administrative support benefit bill clerical counseling clientele client client customer service datum entry database',
#  'accounting budget business management competitive content contract course development client client database management database',
#  'microsoft windows microsoft powerpoint microsoft outlook microsoft access skill',
#  'outstanding leadership',
#  'cash handling',
#  'skill use',
#  'skill use',
#  'microsoft office powerpoint presentation skill social medium branding',
#  'skill',
#  'arbitration automation budget budget concise conflict resolution client client customer service delivery forecasting government',
#  'I be a very organized person with a professional and positive attitude I be great at keep an open dialogue and make myself easily',
#  'work history',
#  'work history',
#  'appointment setter multitasker adaptable microsoft word microsoft excel outlook onedrive excellent phone skill able to work in',
#  'patient assessment',
#  'none',
#  'adobe acrobat benefits blueprint budget planning business case c coach coach council client client datum analysis datum collection',
#  'cable excellent communication interpersonal skill competitive consult cpr customer service instructor ie leadership people',
#  'leadershipâ',
#  'skill course',
#  'account payable art billing call center communication skill cpr certify creative problem solver credit client client relation customer',
#  'academic coach coach contract customer service database delivery financing insurance letter meeting nac networking personnel',
#  'none',
#  'verbal communication',
#  'vast knowledge of strain and their affect',
#  'customer service',
#  'account management e',
#  'background in gpo and formulary process experience in specialty hospital and primary care sale and injectable medication',
#  'billing first aid take message',
#  'none',
#  'anatomy benefit communication skill counseling client client customer satisfaction customer service dependable direction email staff',
#  'skill register counselor expire bls instructor',
#  'administrative art articulate customer service direction financial hire manage marketing   order material neat payroll personnel',
#  'a certify actionscript active directory administrative adobe creative suite   photo audio brochure budgeting business management',
#  'antivirus backup cable cisco hardware contract client client database disaster recovery planning disaster recovery email erp',
#  'a certify active directory billing business process c cash flow cisco cisco router hardware network system content management',
#  'desktop',
#  'air force art agency basic budget oral hardware computer operation configuration management cost analysis datum management dec',
#  'big datum c c chart circuit design hardware datum acquisition datum analyst datum collection datum mining database database dbm dti',
#  'active directory administrative support adobe acrobat architect backup budget clientserver hardware concept client client client',
#  'active directory azure',
#  'academic active directory adp apple architect agency bb behavioral health billing book broadvision cad case management',
#  'asp aspnet model view controller modelviewcontroller ms asp mvc net access adp application software aspnet   associate',
#  'adr advertising arcserve asset management agency backup exec backup banking budget management budgeting business operation',
#  'application',
#  'system administration',
#  'agile framework',
#  'd active directory adobe product apple automation backup broadcast budget planning computer technician hardware installation',
#  'account administrative agency basic programming bookkeeping business communication hardware finance fundraising help desk',
#  'administrative analyst army agency cable cable cat documentation engineer engineering support financial functional government',
#  'a a certification active directory ccna cisco certify network associate hardware consultation client dhcp email fax machine',
#  'google and microsoft suite experience through coursework and classroom implementation',
#  'skill',
#  'net aspnet vbnet adabas ado agile application development asp agency banking banyan billing business analysis business',
#  'none',
#  'a active directory agile avaya call center excellent communication can hardware contract critical think customer service decision',
#  'project management',
#  'aspnet vbnet active directory adonet dreamweaver',
#  'skill certification specialist microsoft certify system engineer mcse  ',
#  'business continuity technology infrastructure file lan architecture business process improvement cdm cisco contract ecommerce',
#  'ad budget change management cisco ios cisco cisco router hardware contract client database dell dell poweredge server',
#  'streamline banking budget business system c cisco close   consult contract crm client customer service ebusiness email',
#  'platformsâ   window    server and professional windows xp proâ   â   â   â   â   â   â   â   â   â   â and home win',
#  'microsoft office suite with deep office   dynamic   project powerapps powerbi flow',
#  'account management ad analyst application development asm agency audit report audit backup budget c capability maturity model',
#  'skill',
#  'skill',
#  'apple art book oral concept conflict resolution cpr creativity design direction documentation first aid flash fundraising draw',
#  'hardware update',
#  'com a active directory backup bay network business systems cisco citrix hardware network system client direction disaster',
#  'âexperienced in strategic planning and execution',
#  'peoplesoft hcm x peoplesoft financial x',
#  'microbial testing endotoxin lal test',
#  'active directory api backup bloomberg bond budget budget business management business planning cisco hardware conflict',
#  'account active directory antivirus antivirus apple arcserve audio backup bgp budgets cisco router citrix hardware contractsdhcp disaster recovery dns firewall firewall focus ftp hardware configuration and troubleshoot hp image ip lan leadership',
#  'ip networking protocol tcpipudphttpsdhcpdnsstphsrpisisripospfmplsftpsmtpipsecvlanvpn',
#  'sap',
#  'accounting accounting system streamline application development bb backup broadband budgeting budget business analysis and',
#  'skill in theme as well drive to',
#  'interpersonal hardware concept content client customer satisfaction database debugging desktop direction documentation engineer',
#  'a active directory apollo army com hardware datum migration dell email engineer flash hp ibm image intel inventory',
#  'language chinese english and japanese',
#  'skill and qualification',
#  'budget cable cisco hardware client documentation electrician feasibility study fund information technology inspector lan material',
#  'active directory antivirus asset management backup exec budget business system cable cisco competitive hardware consulting',
#  'communication',
#  'arabic backup budget hardware client database database management design disaster recovery documentation financial help desk',
#  'photoshop premier art cable hardware computer repair curriculum development client customer service training database department of',
#  'âinfrastructure managementâ   âdata center operation',
#  '',
#  'air force attorney backup balance billing budget business operation interpersonal competitive crm client client dictation disaster',
#  'sale software salesforcecom tapscan',
#  'army clerical good communication skill hardware computer knowledge contract excellent customer service customer service customer',
#  'excellent attention to detail',
#  'active directory antivirus c cable cat computer hardware hardware client client email front page hard drive hardware support html idsinternet access local area network layout domino office application microsoft office   window   microsoft windows   server',
#  'microsoft office',
#  'remote access support',
#  'army basic cable cat   cisco encryption customer support documentation firewall ftp information system information technology',
#  'administrative consultant course development client dc delivery instructor',
#  'year experience security intermediate   year experience customer service expert   year experience network intermediate',
#  'brand budget budget business analysis bi business intelligence business management business object crm datum analysis datum',
#  'active directory microsoft outlook   window   window   system security datum automation circuit design application unix client',
#  'computer trouble shoot microsoft access microsoft excel microsoft powerpoint microsoft word computer security anti hacking',
#  'none',
#  'a acquisition backup budget planning budgeting budget budget business development change management conversion decision make',
#  'active directory dhcp dns win gpo backup budgetingâ   citrix xenapp vmware hyper v dynamic crm dynamicâ   gp',
#  'platform and protocol microsoft window microsoft windows server microsoft active directory microsoft group policy microsoft office',
#  'academic administrative agency basic benefit broadband budgeting budget cobol hardware computer application conference',
#  'administrative and organizational skill',
#  'âable to research and familiarize skill set towards core technology',
#  'agile methodology',
#  'a active directory adobe apache backup exec budget business process c ccna cisco ios cisco citrix hardware crm client',
#  'people center leadership',
#  'accounting analyst business process change management cisco certify coach hardware conversion client direction email',
#  'manage departmental budget for all aspect salary train etc',
#  'army cisco counsel customer assistance database documentation information technology inventory ip lan windows   network',
#  'enterprise resource planning system',
#  'application development lotus approach asset management billing system book budget develop business business process analysis c',
#  'skill',
#  'skillsmarkete operation database asp ms sql server sql sql server technical support testing aspnet budget client database system',
#  'qa offshore annuity testing team lead database qa validation sdlc metric project planning qa test qa testing benefit excel',
#  'database marketing system analyst project management business requirement solution metric qa documentation accountable for',
#  'none',
#  'audio visual game coach customer service fast learner receptionist retail sale landscaping maintenance marketing',
#  'sharepoint',
#  'aspnet   aspnet vbnet active directory backup budget contract negotiation crm datum analysis datum processing database',
#  'administrative duty adobe acrobat schedule appointment asset management agency attorney balance basic billing billing system cashier',
#  'strong decisionmake ability',
#  'streamline agile billing case management contract client customer service database dictation documentation electronic medical record',
#  'enterprise platform',
#  'adabas aix analyst application development budgeting business solution cisco coach database database department of',
#  'procurement clerk purchasing agent',
#  'issue escalation',
#  'aspnet active directory adobe acrobat adobe dreamweaver adobe photoshop application design art billing system business object',
#  'act adobe acrobat after effect photoshop premiere apache branding business process c cisco hardware consultant',
#  'skillssoftware active directory microsoft exchange hp insight manager emc avamar symantec ghost languard network security',
#  'active directory active directory application development budget business management and development business operation business',
#  'american sign language excellent communication customer service database english access excel power point microsoft word work',
#  'inventory database excel training stockroom sql database sap statistic operation sop asset management access asp aspnet',
#  'programming language javajee javascript android html css sql c c',
#  'a',
#  'active directory administrative support attention to detail auditing avaya business process business solution chart cognos hardware',
#  'configuration management process development process improvement database management software development software testing',
#  'project management information design relationship building information technology procedure development scheduling website designms office suite training development quality process event plan work breakdown structure',
#  'active directory premiere ad advertise ibm aix apple architect art catalog color com client digital photography digital video',
#  'antivirus backup exec backup budget cisco router cisco citrix hardware contract client client customer satisfaction database',
#  'account management cable cable help desk linux ms exchange server sharepoint network security desktop support unix hp unix',
#  'account backup billing system budget citrix metaframe excellent communication hardware contract client client documentation',
#  'skill',
#  'router',
#  'budget clientserver customer satisfaction dec direct direction gis government help desk support help desk ibm ibm mainframe',
#  'account payable administrative support benefit oral counseling database data base database email senior management filing form',
#  'executive and legal support business analysis strong communication skill business operation',
#  'proficient in all microsoft application and hris system banner peopleadmin personnel management information pmis system and',
#  'administrative administrative support advertising as set benefit business plan clarify good communication skill interpersonal skill',
#  'skill proofread receptionist research scan scheduling secretarial',
#  'critical thinking',
#  'administrative administrative assistant bi conference database special event file human resource management hr human resource',
#  'aca adp payroll as benefit benefit administration consultation',
#  'benefit central point of contact clerical conference cpr customer service datum entry direct documentation fashion fax focus hire',
#  'administrative administrative support benefit c cash handle closing coaching com interpersonal skill council customer service customer',
#  'benchmarke benefit conflict resolution direction employee relationsâ    performance management personnel policy process',
#  'administrative administrative assistant administrative support attorney benefit call center clerical conference client customer service datum',
#  'skillsadp benefit counseling database employee relation hire hris hr director meeting enterprise newspaper payroll peoplesoft',
#  'adp payroll attorney benefit billing billing ceridian chart coach competitive contract negotiation counseling employee relation',
#  'talent aquisition',
#  'new employee orientation',
#  'excellent telephone manner and high standard of communication skill',
#  'benefit budget client delivery hire human resource hr insurance leadership people management managerial managing market',
#  'management consultation',
#  'assistant manager banking counseling client hire hr marketing ms excel office ms outlook ms powerpoint ms word negotiation',
#  'administrative adp backup benefit bookkeepe clarify competitive customer service database delivery documentation employee',
#  'professional and friendly careful and active listener multitaske careful and active listener',
#  'cash receipt cash handle cash register client customer service datum entry direction employee relation faxes fax machine hire',
#  'customer service receptionist retail sale advertising budget corrective action cost reduction forecasting maintenance office',
#  'adp benefit budget database employee relation special event senior management general manager hire hris insurance krono',
#  'sap r   ms office word excel power point outlook internet application have good understanding of sql html css and',
#  'ada adp art agency benefit benefit administration coach coaching conflict resolution continuous improvement contract decision',
#  'administrative adp backup benefit counseling client customer support documentation form hris human resource human resource',
#  'accounting ad advertise analytical skill benefit billing budgeting client customer service datum analysis delivery documentation',
#  'net academic accounting aim c c closing cold call contract client datum model database datum warehouse fast focus',
#  'ada administrative adobe illustrator art agency benefit ceridian change management decisionmake dca employee relation special',
#  'benefit budget client delivery hire hris human resource hr insurance leadership people management managerial managing',
#  'administrative budget contract customer service documentation expense report financial government hire hr office office',
#  'abc adp adr benefits benefit administration budget coach us army database drive employee relation training',
#  'recruit',
#  'articulate benefit case management employee communication human resource',
#  'work history',
#  'administrative assistant attention to detail banking benchmarke clerical excellent communication competitive consultant customer service',
#  'processing account payable administrative administrative support ad audit report reconcile bank statement benefit bond',
#  'recruit staffing training college recruiting source phone screen interview negotiation recruit event new hire onboarde',
#  'microsoft excel outlook powerpoint wordâ',
#  'administrative duty administrative support adp ad attention to detail basic benefit bi calendar maintenance call center copy data',
#  'high energy',
#  'agency banking basic benefit business administration bi ctc client fast focus form gdc hire hr team build leadership excel',
#  'creative problem solve skill o',
#  'hr maintenance registration staff training access account maintenance general account access control architecture archive',
#  'accountant administrative support benefit billing brochure budget bi chart contract copy client documentation draft engineer',
#  'none',
#  'skill verbal and write communication',
#  'adobe photoshop adp asset management brand brochure content customer care final cut pro graphic graphic hr illustrator',
#  'hris iso recruitment performance appraisal training   development leave   attendanceentry   exit',
#  'adobe acrobat analyst architect balance basic benefit budget management calibration chart consulting contract client datum analysis',
#  'management administrative supportâ coachâ excellent communication skill customer serviceâ frenchâ human resource',
#  'ms office suite',
#  'shrm   hr generalist certificate',
#  'title vii',
#  'skill',
#  'associate relation audits asset protection coach eeoc response succession planning termination customer service retail sale',
#  'carl henry modern sale training clientfocuse effective communication skill event management leadership microsoft office proficient',
#  'benchmarke benefit bi cost reduction documentation engineer executive coach senior management financial fsa hr insurance',
#  'advance excel access word visio power point vba sap hcm success factor compensation microsoft project management',
#  'ada administrative skill administrative coach employee relation training employee english special event hire hris',
#  'skill staff and recruit professional',
#  'employee relation',
#  'none',
#  'administrative ad arbitration agency budget consultant database employee relation hire hris human resource human resource hr',
#  'professional and friendly',
#  'hr advisory service',
#  'type   wpm and key by touch',
#  'word excel powerpoint outlook',
#  'excel human resource ms excel train adp pivot table recruit adp software billing eprise onboarde test administrative',
#  'administrative support antivirus billing budget oral communication conference client customer satisfaction database documentation',
#  'originate new businessâ through professional networking loan review and marketing',
#  'administrative management problem solve pos human resource time management customer service critical thinking great',
#  'business development central point of contact closing client client email employee relation fashion fast fax meeting access mail office',
#  'administrative support adp benefit coach excellent communication conflict resolution conflict resolution consultation creative problem',
#  'accounting agency benefit clientele client client database delivery department of health fax file hr insurance marketing plan',
#  'account adp analytical skill ap ar benefit billing call center great communication skill interpersonal skill credit client customer',
#  'account payable account receivable benefit benefit administration billing budget budget coaching contracts council client client dc',
#  'peoplesoft microsoft office suite adp and sapâ',
#  'ms office word excel outlook and powerpoint sap database applicant tracking system   strong organizational and adminstrative skill',
#  'onboarde',
#  'human resource management skill',
#  'recruit',
#  'skill and mrp vacation calendar',
#  'account payable',
#  'account ada advertising benefit benefit   administration bookkeepe budgeting business law business research business startup',
#  'selfmotivate detail orient organize customer focus',
#  'benefit budget analysis budget budget coaching contract negotiation documentation training employee event plan special event',
#  'leadership development',
#  'ada art benefit benefit administration biotechnology brand budget change management contract negotiation contract negotiation',
#  'ada benefits benefit administration call center coach conflict resolution employee relation training employee senior management',
#  'abra academic benefit benefit administration bill bi ceridian conflict resolution crystal report hris human resource hr',
#  'skill hr strategic planning training   development performance',
#  'computer skill',
#  'payrollâ â benefits administration â employment law ââ fmlaadaeeowc ââ hr policy',
#  'human resource management',
#  'microsoft office suite sap kronos ibm adp ats mss hrss and oracle workbrain t',
#  'staff recruitment   retention',
#  'account payable account receivable ada administrative and support ad advertise backup benefit benefit administration brochure',
#  'skill and qualification',
#  'ada advertisement benefit budget chart competitive counseling database documentation employee relation fire form hire human',
#  'adp benefit closing coach coach competitive customer service database hire hris hr insurance logistic director mentor',
#  'new employee orientation',
#  'academic ai attention to detail backup benefit benefit administration budget cash receipt coach contract critical thinking customer',
#  'ada approach arbitration auditing business strategy case management contract negotiation crisis management finance functional hrishuman resource human resource hr information system iso leadership material science money negotiate negotiation negotiation',
#  'administrative banking basic benefit call center clerical coach client client database documentation employee relation fax filing',
#  'office support',
#  'ada adp benefit clarify employee relation human resource human resource hr insurance law enforcement mediation ms office',
#  'professional human resource certification phr june',
#  'system excel outlook power point visio one note share point sap advise hr siebel talx autonomy survey monkey taleo',
#  'bullhorn boolean search google resume search linkedin xray search the ladder github tech fetch monster career builder',
#  'academic autism book client customer service database internet explorer director excel powerpoint window microsoft word',
#  'agency budgeting budget business strategy close cold call interpersonal communication skill excellent communication oral contract',
#  'microsoft office with modern classroom technology',
#  'anatomy aseptic technique bachelor biology calculator calibration content credit database department of health dna educator',
#  'national board certify',
#  'I have a lot patience I communicate really well with child',
#  'train',
#  'brand business case interpersonal oral critical thinking functional lesson planning meeting microsoft office outlook relationship building',
#  'instructional design teaching progress monitor course',
#  'outlook excel word powerpoint quickbook and onenote',
#  'classroom management',
#  'accounting credit invoice budget account payable cash of account accountant audits billing buyingprocurement customer',
#  'discharge planning lesson plan evaluate patient supervision',
#  'none',
#  'microsoft office',
#  'classroom management',
#  'purposeful lesson plan',
#  'game increase recruitment associate budget fundraising health and wellness liaison recruiting arrangement exchange progress',
#  'acute care art autism basic biochemistry biology chemistry cpr focus fundraise law patient care pediatric physical therapy',
#  'people skill',
#  'academic art coach continuous improvement council critical thinking educational program english instruction leadership leadership',
#  'microsoft office microsoft windows xp professional word excel powerpoint publisher internet browser learn google chrome',
#  'microsoft excel experienced wpm',
#  'classroom management',
#  'meticulous attention to detail',
#  'filing and datum archivingâ',
#  'bookkeepe conference email english   english   instruction lesson plan material meeting mail money office notary public payroll',
#  'current virginia',
#  'positive reinforcement method',
#  'assessment',
#  'skill   classroom management   assessment   special educationteacher for the visually impair   elementary',
#  'academic planning administrative skill case management clericalâ   documentation and shorthand researchâ   lesson planning newsletter',
#  'bookkeeper child care conference counsel documentation educator email human resource internet navigation meeting mentor',
#  'cash handling cost control critical thinking financial accounting inventory level lesson planning personnel position quality receive',
#  'accounting approach attention to detail backup cash handle cash register cashier closing coaching communication skill conflict',
#  'leadership motivation management speak listen counseling teach computer literacy training editing organize development',
#  'cpr',
#  'creative lesson plan',
#  'microbiologãa director general directora industrial jefe de laboratorio acta bpm bpm business process management c carne de',
#  'increase training coaching teach clerical filing class comprehensive large array data stewardship system liaison translate',
#  'resultsoriente',
#  'ms office proficient',
#  'academic interpersonal skill economic english functional instructional design lesson plan manage   material math teacher teamwork',
#  'child care family servicing conference first aid instruct lesson plan direct meeting mental health management information system',
#  'enthusiastic people person great organizational skill',
#  'art conference edit facsimile instruction leadership skill note material meeting access excel microsoft office outlook powerpoint',
#  'detail and accurate transcription ability',
#  'academic photoshop advertising cancer competitive conference consultant content creative design creative problem solve client',
#  'behavior model',
#  'administrative arts â basic coach customer service â inspect instruction inventory laundry transport material â meal prep personnel',
#  'work history',
#  'operate system window xp android and msdo software autodesk civil d autodesk autocad autodesk inventor',
#  'excellent',
#  'skill use',
#  'account payable advertising bookkeeping budget chart customer service financial reporting payroll spreadsheet',
#  'administrative content material meeting policy problem solve progress teach verbal communication skill write',
#  'academic budget coaching conference curriculum development educator instruction lesson planning lesson plan math access',
#  'team player and effective collaborator',
#  'none',
#  'â counselor academic native spanish speaker leadership workshop goal setting and implementation effectively work with parent time',
#  'accounting account payable administrative aol audit banking benefit budget business work content counsel client customer',
#  'strong interpersonal skill',
#  'bilingual speak and read fluently in english and spanish demonstrate your ability to work well with a team handle detail coordinate and',
#  'academic chart delivery equity instruction lesson plan math microsoft office progress report',
#  'none',
#  'skill',
#  'ms office',
#  'academic art interpersonal skill instruction lesson plan note material meeting powerpoint camera progress teach training program',
#  'corporate trainer member ge capital presidents council quality control and customer service management motivational strategist',
#  'skill medical terminology',
#  'e',
#  'creative at lesson planning and handson instruction',
#  'administrative support scheduling appointment approach art I attention to detail billing communication skill customer service dependable',
#  'cash handlingprofessional and friendlycareful and active listenermultitasking',
#  'organizational skill',
#  'skill proficiency in microsoft office capable of integrate these program with the coursework teach sound decision maker give',
#  'chart excellent communication conference conflict resolution critical thinking focus instruction instructional design lesson plan',
#  'cpr certify',
#  'strong communication skill',
#  'skill use',
#  'none',
#  'word excel and powerpoint ãââadvance knowledge and skill in use media tool for teach purpose such as',
#  'adobe photoshop adobe premier benefit communication skill conference curriculum development flash human resource instruction',
#  'administrative administrative support budget communication skill excellent communication contract database financial report grant',
#  'average computer literate',
#  'behavior model',
#  'computer literate driver listen natural packaging quality rapport teach',
#  'skill use selfdirection team player trouble shoot record keeping and problem solve management of volunteer base that run group',
#  'microsoft office word excel powerpoint outlook infinite campus',
#  'art content content development   management content creation curriculum development database dimension event plan',
#  'mathematic tutor good team member communication childcare manage hire merchandise recruiting selling recording',
#  'time management',
#  'conduct peer council with youth',
#  'ââ â â â â â â â   computer literate and valid texas driver licenseinsurance',
#  'â well verse with the standard of hygiene and sanitationâ demonstrate ability to perform duty in a busy environment',
#  'number',
#  'arbitration communication skill cpi creative problem solver customer service insurance law enforcement team lead logistic director',
#  'bilingual farsi and english',
#  'highly effective teacherâ',
#  'conflict resolution course development critical thinking curriculum development â instructional design â research staff development teaching',
#  'superb communication both verbal and written',
#  'cpr creative thinking delivery first aid policy problem solver safety teacher team player phone time management',
#  'proficient epic word lotus interqual nice symposium foundation azz cardfile',
#  'none',
#  'prove administrative highly organize',
#  'work proficiently with minimal supervision fluent communication skill demonstrate daily through interaction with various patient and',
#  'microsoft office excel power point and access expertise internet pcmac software proficiency',
#  'skill matrix ltd new york ny   project management catapult inc parsippany nj',
#  'excellent interpersonal hr and administrative skill',
#  'none',
#  'organize',
#  'none',
#  'salesforcecom oracle clarity ppm tool microsoft office various other system',
#  'bilingual speak read and write english and spanish fluently',
#  'account payable art audio read blueprint book budget cash register closing cost control crisis intervention customer service delivery',
#  'accounting businesscase chart hardware configuration management counseling client documentation financial statement graphs information',
#  'patientfocuse care excellent interpersonal skill compassionate and trustworthy caregiver time management effectively interact with patient',
#  'skillsoasisâ',
#  'build loyal business relationship with patient colleague physician family and ally healthcare professional across a premier fastpace',
#  'issue resolution',
#  'academic acute care anatomy armed force basic chart oral database database emergency medicine emotional support english form',
#  'can lift up to   lbs',
#  'staff management ability',
#  'register nurse healthcare medicare client quality assurance staff business operation contract operation system analysis',
#  'organizational skill write communication skill verbal communication skill cultural awarenessâ   microsoft type skill ability to focus',
#  'skillsbille chart clarify client dds diagnosis documentation focus government regulation rhit home health insurance law legal managing',
#  'account management key account sell product expertise or sell training budget business plan educational program market',
#  'bilingual in spanish read write and speak',
#  'time management effective communication trouble shoot problem solve cloud technology skype proficient microsoft office suite',
#  'premier advertisement agency basic business development close corporate communication client client database database',
#  'complaint handling and resolution',
#  'develop the history of celebrex   timeline of event for celebrex and why it be',
#  'art assist live cna coach customer service financial home healthâ nursing receive shipping web design and',
#  'season healthcare advisor excellent communication skill creative problem solver innovative critical thinker leader change driver',
#  'accounting account receivable auditing balance billing business communication business plan client client client liaison customer service',
#  'biotechnology and pharmaceutical',
#  'administrative function basic benefit chart clerical crm client client fire focus form insurance inventory issue receipt excel',
#  'accounting adobe adr analyst auditing billing budget development budgets chart contracts cpt crystal report customer satisfaction',
#  'project management',
#  'active directory air force basic bi business process database management database fsa functional gui instruction java local',
#  'strong p',
#  'budget closing competitive concept council client client customer service delivery driver ecommerce focus hr leadership marketing',
#  'medical terminology expert',
#  'active learn calendaring computer proficiency coordination creative problem solve critical thinking customer need assessment',
#  'administrative budget cancer chemotherapy database dna fast form grant writing law marketing mentor process program',
#  'graduate assistant   team lead',
#  'reorganization procedural evaluation',
#  'ada bill budgeting business process call center consultation contract client client customer satisfaction customer care datum collection',
#  'customer service receptionist retail sale administrative assistant correspondence medical assistant training client',
#  'customer service delivery fax filing insurance microsoft office suite management information system read scheduling technical',
#  'acute care administrative golive streamline adp balance benefit billing business analysis business operation call center contract',
#  'strong interpersonal skill',
#  'program knowledge',
#  'audits quality assurance maintenance database clerical clerk general clerical outpatient clinical trial clinical research audit case',
#  'time management effective communication trouble shoot problem solve cloud technology skype proficient microsoft office suite',
#  'prove patience and selfdiscipline',
#  'academic acrobat adobe photoshop business planning coach contract negotiation drive endocrinology english financial illustrator',
#  'agency budget business plan client client customer satisfaction database financial financial advisor forecasting hire leadership manage',
#  'accounting bridge budget budget oral community health conference critical thinking datum processing database database management',
#  'strong p',
#  'marketing fundraising graphic design healthcare billing claim receivable accountable for auto insurance compensation',
#  'clinical training',
#  'type great then   word a minute',
#  'budget proficiency',
#  'streamline process business object cognos crystal report customer service datum analysis database financial invoicing manage',
#  'clarify can focus law nursing process scheduling statistic teach',
#  'human resource scheduling and payroll',
#  'business administrator',
#  'skill',
#  'none',
#  'skill and accomplishment',
#  'none',
#  'product development',
#  'effective and strong communicator write and oral skill',
#  'administrative customer service datum entry event coordination merchandisingâ   networkingâ   report scheduling travel arrangement',
#  'flexible   adaptable',
#  'strong leadership skill',
#  'administrative administrative support attention to detail benefit cash handling com critical care customer satisfaction customer service',
#  'apm administrative administrative support streamline anatomy agency behavioral health billing budget business object call center',
#  'administrative support bookkeepe counseling cpr clientele client client customer service datum entry datum management email image',
#  'accounting agency attention to detail billing budgeting business development case management chart interpersonal communication contract',
#  'people skill strong interpersonal skill enthusiastic people person advance problemsolve great organizational skill advanced time',
#  'account management',
#  'excellent customer service',
#  'high customer service standard',
#  'confidential datum protection',
#  'acquisition cms content contract negotiation contract contract management client database direct documentation estimate',
#  'skill',
#  'academic adp payroll c client client financial fluent in french infection control insurance mental health excel microsoft office suite',
#  'epic microsoft office suite wordexcelpowerpoint healthcare system insurancebille sorian scheduling healthmedical record',
#  'payroll training hedi audits case database billing business consultant business development code healthcare medicare outpatient',
#  'team leadership',
#  'skill client development project management program development finance analysis training   development',
#  'administrative function administrative support art automobile basic change bed linen benefit bookkeepe chart cpr client',
#  'skill   master new concept quickly   initiate document control and processing information   high',
#  'digital medium digital marketing social medium email direct mail mobile promotion brand customer acquisitionretention analytic',
#  'skill teach file english',
#  'electronic',
#  'skill operation personnel supervisiontraining',
#  'acute care billing case management chart chemotherapy closing coach client client discharge plan insurance director meeting',
#  'accounting software administrative audio benefit c contract client datum management dc documentation senior management form',
#  'care for patient with musculoskeletal disease and disorder assist with activity of daily living administer intravenous medication',
#  'telecommunications knowledge',
#  'â build team with humility',
#  'patient service',
#  'academic accounting administrative balance biology business development business law chemistry interpersonal can consult',
#  'ad autism benefit billing coach coach client client datum processing delivery driver file financial statement hire inventory',
#  'good judgment',
#  'excellent interpersonal skill',
#  'microsoft office   year talent acquisition talent management recruit staffing business development training and development',
#  'skill use',
#  'agency benefits hardware cpt code client client customer service direction financial icd information system insurance leadership',
#  'ad advertising book brochure cash register content credit client client customer service experience direction email event plan',
#  'electronic medical database',
#  'administrative ambulance basic cpr certify first aid inventory life support logistic microsoft office office personnel fast learner',
#  'lean six sigma improvement methodology advanced analytic data management process and performance improvement planning financial',
#  'net aspnet active directory agile ajax api architect automate bi business intelligence cascading style sheet excellent',
#  'dasylab labview mechanical electrical leans hydraulic testing test stand fabrication',
#  'tutoring teaching mathematic algebra geometry english content management documentation middle school   high school math',
#  'program management',
#  'exceptional time management',
#  'net photo agile analyst apple automation banking budget business plan closing com consulting content contract credit encryption',
#  'accounting apple computer asset management automation basic blueprint budget budget c ca hardware concept contract client',
#  'd agile ajax approach bb budget c c competitive css database delivery ecommerce expert system fund hire html',
#  'microsoft office',
#  'ââ â   year of material management experienceâ   with state and federal government â',
#  '  year of experience with cad package solidwork autodesk inventor autocad catia ptc creo',
#  'none',
#  'aspnet   academic clustering consult curriculum development customer satisfaction datum analysis datum mining datum warehouse',
#  'autocad c c client hazop iso   logic microsoft office work minitab optimization plc proe profit project',
#  'api atl audio backup broadcast c cli hardware concept content management content client client documentation dynamic',
#  'leadership',
#  'knowyourconsumer kyc',
#  'assembly atm cadence calibration can hardware dc debug ethernet graphic iso   labview layout linux os logic',
#  'automotive basic broadcast cable cable cable carpentry chill can conversion council sc direction documentation electrical system',
# ...
#  'streamline ad balance sheet basic budgeting budget budget business process capital expenditure cognos conference contract',
#  'accounting approach balance balance sheet bank reconciliation banking bookkeeping book keep budget budget c cash flow',
#  'academic accounting auditing balance billing cash handle credit customer service datum entry fax file financial fund home office',
#  'project management experience',
#  'skill automobile financing negotiating goal se ing customer service creative problem solve',
#  'budgeting forecasting',
#  'accounting software account payable banking database fix asset prepay expense marketing and sale access excel microsoft office',
#  'creative writing',
#  'â excellent attention to detail',
#  'account general accounting accountant articulate balance balance sheet bank reconciliations bank reconciliation banking',
#  'work history',
#  'ms office ms project visio microsoft dynamic gp epicor quickbooks salesforce projector psa',
#  'balance sheet analysis budgeting forecasting hyperion excelâ powerpoint word oracle',
#  'corporate accounting accounting operation audits cash file financial statement general ledger reconciliation',
#  'advertising benefit business management   closing consultant counsel customer relation customer satisfaction documentation finance',
#  'skill   prove ability to produce formal write report with the subheading of table of content executive summary',
#  'accounting accounting software budget contractual procedure',
#  'dari persian pashto english russian arabic urdu',
#  'academic accounting account payable account receivable administrative art agency benefit bill clerical conflict resolution counsel',
#  '  â',
#  'automobile bi competitive contract feature finance financial hospice inspect leadership marketing negotiating negotiation',
#  'accounting general accountingâ   acquisition budget controller cost analysis and analytical reporting credit facility management',
#  'contract credit client database finance financial financial report policie sale',
#  'work history',
#  'analytical skillsâ',
#  'preparation of monthly datum for submission to cpa for financial statement preparation account payable which include vouchere verifying',
#  'business process reengineere',
#  'pl management project management communication leadership finance operation tax pp oc compensation service financial',
#  'academic',
#  'none',
#  'account reconciliation accounting accounting software account payable account receivable account receivable administrative approach',
#  '  â',
#  'budget budget business analysis cisa contract contract management financial financial analysis forecast functional information',
#  'accpac plus adp aggreso business work',
#  'leadershipcommunication skill',
#  'account ad auditing benefit budgeting budget budget business process client driver essbase senior management finance financial',
#  'ad bb budget business intelligence chart credit datum analysis datum warehouse database decisionmake executive management senior',
#  'benefit budget business plan monthly quarterly billing flow chart conflict resolution database documentation hire hr generalist',
#  'excellent people and selfmanagement technique excellent client or business partner relation excellent write and oral communication',
#  'accounting accountant accounting system accrual acquisition golive ap ar backup balance sheet bank reconciliation benefit',
#  'account financial audit general ledger ap purchasing quickbook',
#  'skill financial reporting   analysis ifrs and we gaap budgeting',
#  'work history',
#  'financial statement analysis budgeting forecast strategic planning financial modeling strong communication interpersonal and',
#  'leadershipcommunication skill',
#  '  â',
#  'accounting accounting software auditing banking bond budget management budgeting cash flow cash management credit derivative',
#  'accounting accounting software account payable administrative aia billing billing budget clarify conference client client datum base',
#  'sap business warehouse business planning and consolidation business object sas crystal reporting',
#  'âmicrosoft excel   intermediate skill level',
#  'career minded personality with expertise in sale and managementâ   strong communication and customer service skill experience in create a',
#  'work history',
#  'account general accounting auditing balance sheet billing budget closing contract cpa credit client client finance financial',
#  'team worker',
#  'sapsap',
#  'account administrative adp automobile balance cash deposit cash handle clerical closing draw finance financial fund inventory',
#  'financial planning and analysis budgeting report strategic planning forecasting operation',
#  'bank reconciliation analysis bond budget analysis cash flow general ledger inventory investment interest payable   saving payroll',
#  'accounting account payable account receivables account payable accrual administrative duty backup bank reconciliation billing',
#  'extensive customer service',
#  'administrative ap ar billing conference contract client client customer satisfaction customer service customer support database',
#  'budgeting cost management financial reporting   analytic investment and return on investment roi npv and eva process',
#  'accounting account payable account receivable accrual ad ap agency auditing balance sheet billing billing budget development',
#  'photoshop advertising arabic autocad business operation com client customer service dialog engineer english estimate filing',
#  'key by touch account payable account receivable administrative billing budgets budget cisco close interpersonal credit client',
#  'academic photo agency atm c computer application credit critical thinking customer service database debit decision make detail',
#  'advertising make appointment art closing counseling credit client customer service database email file finance form',
#  'financial analyst budget forecasts sarbanes oxley sarbanesoxley sox sox testing marketing budget finance financial reporting',
#  'premier streamline book business plan communication skill concise datum analysis datum collection decision support delivery designing',
#  'accounting accounting system account payable account receivable acquisition benefit billing bookkeepe budget cash flow coach',
#  'quickbooks workamajig ms office suite indesign photoshop concrete cms â google analytics googledocs intervals seosem',
#  'account budgeting budget budget business development business management business process business solution customer',
#  'familiar with a vast array of finance activity and management skill knowledge of basic computer',
#  'account reconciliation accounting accounting system ap agency auditing balance banking billing budget budget coaching hardware',
#  'skill budgeting and financial management superior time management lean implementation',
#  'automotive billing closing credit leadership process improvement project management rapport relationship building sale',
#  'proficient in microsoft office suite application windowswordexcelpowerpointoutlook',
#  'account accrual ad ap balance sheet bloomberg budget budget business intelligence business plan c cash flow client database',
#  'time management',
#  'work history',
#  'erp implemenation',
#  'reporting and documentation',
#  'communication skill write   verbal',
#  'account adp payroll ad automate budget budget client database decision make direction senior management senior management',
#  'reconcile various general ledger account explain variance and prepare report for review with department on a monthly basis',
#  'strategic financial planning',
#  'exceptional interpersonal communication',
#  'accounting account payable account receivable attention to detail benefit budget development budget strong interpersonal skill contract',
#  'excel access powerpoint sapâ oracle mfg pro hyperion khalix trahq',
#  'accounting accountant account payable account receivable administrative administrative function adobe illustrator photoshop adp',
#  'account reconciliation accounting account payable accrual streamline advertise arabic balance sheet trial balance bank reconciliation',
#  'trade finance operation',
#  'accounting accountancy computerized accounting trial balance balance sheet bank',
#  '  fast learner',
#  'accounting audit report billing budget budget closing cost accounting certify public accountant cpa decision support direction senior',
#  'hyperion planing essbase sap r oracle   sap bpc business object sharepoint ms office',
#  'project management',
#  'budget control   administration',
#  'budget budget business analysis contract contract management financial forecasting and financial financial operation functional',
#  'account administrative budget planning business strategy cash flow cash management competitive customer satisfaction finance financial',
#  'photo credit client customer service digital camera edit fashion flash instruction inventory meeting policy research sale set design',
#  'excellent quantitative skill',
#  'dependable independent worker',
#  'skill use participate in various',
#  'inside and outside sale customer service salesforce act and goldmine crm allscript software outlook practice fusion software',
#  'microsoft office suite calendar critical thinking travel arrangement',
#  'sale benefit increase pediatric marketing account executive client of sale sale quota solution its closing award channel',
#  'âcomputer and electronic',
#  '  good at communicate and interact with customer',
#  'business development',
#  'speak',
#  'sale expertise',
#  'ad attention to detail customer service datum base inventory office presentation quality control sale phone',
#  'skill',
#  'honest reliable drive enthusiastic people person self motivate',
#  'excellent customer service customer service work fast learner roofing',
#  'current trend knowledge',
#  'ms office suite word excel outlook powerpoint sharepoint visio lm centra digital marketing mailchimp webtrend treehouse',
#  'critical thinking',
#  'cash register close computer literate credit customer relation customer satisfaction customer service employee relation fluent in english',
#  'effective at multitaske',
#  'skill and qualification',
#  'bilingual bangla   english',
#  'I have have some extended class in interview and hiring of staff as well as goal setting and the follow through with staff as well as with the',
#  'skill',
#  'billing brochure â client editing email event production film marketing excel microsoft office outlook powerpoint publisher',
#  'cpr first aid report write andâ documentation leadership',
#  'approach budget coach coach interpersonal communication computer knowledge consultant conversion credit client',
#  'bilingual',
#  'event management and promotion',
#  'skillspeople skill new business development sale client management customer service management marketing communication',
#  'none',
#  'familiar with john deere ag and lawn equipment   massey ferguson ag equipment kubota ag and lawn',
#  'literate ms excelmicrosoft word as',
#  'communication skill creative problem solver publisher ms window quick learner sale phone',
#  'assembly hardware customer satisfaction customer service database direction driver electronic forklift macola work neat camera',
#  'quick learner',
#  'accounting account receivable streamline assist live budget excellent communication client customer satisfaction customer service',
#  'work well as a team member or independently perform sale marketing and market trend research identify and test market setup',
#  'skill organize summary of',
#  'cash handle clientele excellent customer service customer service fast financial frame honest meal preparation micro office window',
#  'accounting benefit budget excellent communication contract resolve customer complaint employee relation fire hire inventory labor',
#  'none',
#  'none',
#  'customer service',
#  'â cash management communication skill computer literatecustomer service',
#  'balance book database debit documentation email form front office im inventory legal note money outlook enterprise newsletter',
#  'dependable',
#  'advertising balance sheet calculator cash receipt cash register catalog commodity credit critical thinking resolve customer complaint',
#  'ask benefit business plan client direction feature fire hire inventory marketing strategy real estate sale sale manager',
#  'key by touch',
#  'relationship sell quick learner resolutionoriente reliable and dependable cheerful and energetic dedicated',
#  'advertisement calculator cash register competitive credit client customer relation customer service database email issue receipt',
#  'blueprint read blueprint interpersonal   communication conference customer relation excellent customer service direction hire layout',
#  'great communication skill excellent customer service customer service experience customer service fast focus inventory control multi',
#  'advertising book excellent communication computer knowledge contract client documentation innovation inventory team build',
#  'professional and friendlyâ',
#  'billing billing system budget budget business management coldcalle client customer service datum analysis database facility maintenance',
#  'strong analytical skill',
#  'highly effective leader in extreme situation as well as normal condition posse the ability to place the correct personnel with the appropriate',
#  'lee green associate',
#  'skill',
#  'account receivable adp closing cold',
#  'pricing sale inbound and outbound audit documentation filing inspection maintenance medical record basis receptionist customer',
#  'ability to clarify the nature of a problem evaluate alternative propose',
#  'advertise cash register color cooking critical thinking customer service decision make english maintain inventory inventory listen',
#  'none',
#  'trust key holder',
#  'relationship sell',
#  'time management',
#  'work history',
#  'sale',
#  'skill',
#  'vendor relation',
#  'start out hand charting but now at north computer chart on cerneri run the tmr laser in the heart room operate the cryo and ablation',
#  'cashier',
#  'excellent people skill',
#  'account management customer service strong sale experience bilingual',
#  'cash register cash register close computer literate credit customer relation customer satisfaction customer service dependable inventory',
#  'billing credit customer service experience in filemaker manage major account vip customer medium production managingâ new',
#  'certify forklift operator',
#  'caregiver cashier credit customer service debit english home care neat receive selfstarter telephone well organize',
#  'attentive to small detail',
#  'billing credit english form insurance prepare invoice issue receipt listen money persuasion policy read record sale',
#  'skill',
#  'sale software ubersmith',
#  'self starter',
#  'teamwork',
#  'customer service retail sale associate cashierm exceloffice powerpoint word',
#  'osha inspection',
#  'sale telephone inventory point of sale credit cash customer service receptionist retail sale answer associate client exceed',
#  'career overview',
#  'sale sale representative in sale corporate sale operation sale and account and account for and sale billing business',
#  'adobe cable hardware copy customer service datum entry direction fax ie inventory loss prevention mail win monitor pc',
#  'sale sale management staff workflow account management accounting administrative support business plan consultation',
#  'extensive experience of plan project management',
#  'proficiency in microsoft office suite adobe creative suite ronlynn apparel software both mac and pc platform social medium include',
#  'inventory control procedure',
#  'customer service',
#  'experience of   year in the field of design as an illustrator',
#  'benefit billing competitive contract cpr client delivery dependable documentation driver equipment operator expense report first',
#  'office suite sql google product',
#  'motivate seller â   â   â   â   â   â   â   â   â   â   â   â   â   â   â â',
#  'account reconciliation administrative advertising benefit brochure communication skill contract creative problem solver credit client',
#  ...]

# %% [markdown]
# **Extracting Education from the PDF and Preprocessing it**

# %%
education_list = []

for path in pdf_path:
# Open the PDF file
  with open(path, 'rb') as pdf_file:
      pdf_reader = PyPDF2.PdfReader(pdf_file)

      # Extract text from the PDF
      pdf_text = ''
      for page in pdf_reader.pages:
          pdf_text += page.extract_text()

      # Define regular expressions for matching job category, skills, and education
      education_pattern = r'Education\s+([\s\S]*?)(?=\n(?:Summary|Organizations|Certifications|Professional|Affiliations|Publications|Company Name|Activities|Licenses|Language|Honors|Speaking|Selected Trainings|Skills|Experience|Highlights|Interests|Additional|Accomplishments|Personal Information)|\Z)'

      # Extract category, skills, and education using regex
      education_match = re.search(education_pattern, pdf_text, re.DOTALL)

      # Extracted information
      education = education_match.group(1).strip() if education_match else "None"

      education_list.append(education)

# %%
education_preprocessed = []

def preprocess_text(text):
    # Remove URLs
    text = re.sub(r'http\S+', '', text)

    # Remove email addresses
    text = re.sub(r'\S+@\S+', '', text)

    # Remove special characters and digits
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\d+', '', text)

    # Convert text to lowercase
    text = text.lower()

    # Remove newline characters
    text = text.replace('\n', '')

    # Tokenize using SpaCy
    doc = nlp(text)
    tokens = [token.text for token in doc]

    # Remove stopwords using NLTK and SpaCy
    stopwords_nltk = set(nltk.corpus.stopwords.words("english"))
    stopwords_spacy = nlp.Defaults.stop_words
    tokens = [token for token in tokens if token not in stopwords_nltk]
    tokens = [token for token in tokens if token not in stopwords_spacy]

    # Perform stemming using NLTK
    stemmer = nltk.PorterStemmer()
    tokens = [stemmer.stem(token) for token in tokens]

    # Perform lemmatization using SpaCy
    tokens = [token.lemma_ for token in doc]

    # Join the preprocessed words back into a string
    preprocessed_text = " ".join(tokens)
    return preprocessed_text

# Example usage
for text in education_list:
  preprocessed_tokens = preprocess_text(text)
  education_preprocessed.append(preprocessed_tokens)

# %%
education_preprocessed
# Out:
# ['master of science   human nutrition    university of new haven ï¼ city   state   usaminor in nutritional genomicsthesis submit in partial fulfillment of requirement for degreeâ   gpabachelor of science   human nutrition and dietetic    university of jordan ï¼ city   jordan   gpa',
#  'johnson c smith university   bachelor of science   business administration city   statebusiness administration concentration in marketing and sale management',
#  'high school diploma    eagan high school ï¼ city   state',
#  'and traininghigh school diploma   general   belton high school   city   state',
#  'high school diploma   university of texas   city   state communicationsvolunteeringblue dog rescueb friend animal sanctuary',
#  'and trainingbachelor degree   psychology government december   university of tampa psychology government healthy lifestyle principlesfoundation of strength and conditioning cpr first aid ae les mill bodypump guardian ad litem volunteer and advocacy training',
#  'and trainingnorthern high school high school diploma',
#  'high school diploma   high school   automotive skill general education automotive skill general education career management class',
#  'master of science   nursingmaster of business administration university of phoenix academic achievement master of science innursingmaster of business administration healthcare university of phoenixbachelor of science   nursing valparaiso university bachelor of science in nursing valparaiso universitybachelor of science   exercise science ball state university bachelor of science in exercise science ball state university',
#  'master of business administration mba   general management   university of phoenix city   state general managementbachelor of science degree bs   exercise science   seattle pacific university city   state exercise science',
#  '  centennial high school gpa gpa   full time student and athlete all four year gpa   collin college full time student take my basic course texas tech',
#  'bachelor of science   kinesiology   east carolina university   city   state',
#  'associates degree   business management    harford community college ï¼ city   state   united statesemphasis in business management and biologyemergency medical technicianbasic emergency vehicle operator cprae certify   fire science    maryland fire and rescueinstitute ï¼ city   state   united statesdiploma    north harford high school ï¼ city   state   united statesgraduate with honorspresidential academic achievement awardstudent government representative',
#  'high school diploma jun   jay m robinson high school concord north carolina united states weighttraine   physical education compete in high school basketball   varsity   compete in track and fielddec   belmont abbey college belmont north carolina united states gpa gpa   gpa world instructor training school charlotte nc united states jun aug   pass both the practical andwritten exam for a certify personal training certification',
#  'certificate   wellness coach    wellcoache school of coachingmaster of science   exercise science and health promotion    california university of pennsylvania ï¼ city   state   usabachelor of science   nutrition    indiana university of pennsylvania ï¼ city   state   usa',
#  'bachelor of science   exercise science and human performance     exercise science and human performanceaa   exercise science     mesabi range community college ï¼ state exercise scienceafpa nutrition certification completion buena vista university ï¼ city   state',
#  'for sscv presentdirector of facility and operation minturn fitness center presentnote accomplishmentswomen fis team coach for sscv produce the most athlete from a single program to make the usst during the   year span usst disabledparalympic alpine coach of the year design and execute firstever dedicated sscv strength and conditioning program design and execute firstever hour continue education program for ski and snowboard club vail full and parttime athleticstaff   staff member direct allinclusive human performance program for sscv include strength and conditioning sport psychology nutrition andmedical intervention presentpropose design build and provide operational oversight of all facet of the minturn fitness center on the vssa campus includingoperation hire membership management marketing and advertising programming for general population junior highschool andelitevip athlete present at the nfl combine in indianapolis i d on the subject of power training for olympic success spring',
#  'bs   kinesiology    university of montevallo ï¼ city   state kinesiology complete numerous course in sport health and fitness withconcentration in health promotionfirst aidcpraed certify',
#  'associate of art   general business mesa community college ï¼ city   state general business currently attendinghigh school diploma james madison preparatory school ï¼ city   state',
#  'bachelor of science   healthcare administration    southwestern college ï¼ city   state gpa summa cum laude graduatehealthcare administration summa cum laude graduateassociate of apply science   leadership and management    us air force air university distance learningtraining specialize in leadership management managerial communication total quality management management theory management byobjective motivation counseling and diversityassociate of apply science   fitness recreation and service management    community college of the air force fitness recreationand service managementskillsaccount management account receivables administrative support subordinate counseling computer proficiency customer servicefinancial report reconcile fund management inventory logistic director risk management secretarial duty communication skill totalquality management executive management support file grammar internet research letter and memo lotus note microsoft excelmicrosoft office suite microsoft outlook microsoft powerpoint microsoft word minute take multitask management organizational',
#  'bs   business administration    northern arizona university   city',
#  'none',
#  'master of science   communication   medium management    virginia commonwealth university ï¼ city   state   usa communication medium management concentration communication marketing and public relation coursework in business management with a focus on medium',
#  'bs   holistic nutrition    clayton college of natural health holistic nutritionaccounting   management human resource    california state university accounting   management human resourcesskillsmicrosoft windows microsoft powerpoint microsoft outlook microsoft access skill internet explorer and social medium',
#  'bachelor of science   sport and leisure study the ohio state university',
#  'and trainingfitness nutrition certification   personal training certification   nutrition science human anatomy and physiology weight loss management national academy of sport medicine city   statecoursework in health and physical educationexercise science and kinesiologypersonal trainer certificateattende seminar on weight loss managementcoursework in nutrition science human anatomy and physiologybachelor of science   nutrition science human anatomy and physiology clark atlanta university city   statecoursework in nutrition sciencehuman anatomy and physiologymember of biological science club gpa',
#  'bachelor of science   criminal justice anthropology    the state university of new jersey ï¼ city   state   united statesgpa',
#  'high school diploma   general education    camden county high school ï¼ city   state general educationwilling to relocate anywhere',
#  'ms   kinesiology    university of texas el paso ï¼ city   state   usgpa   teacher assistant for undergraduate and graduate class',
#  'bachelor of science   natural health study    clayton college of natural health   city   state work historywellness director    to current',
#  'mba   alternative dispute    pepperdine university city   state alternative dispute the emphasis of my mba be in alternative disputeresolution which focus on leadership business negotiation collective bargaining arbitration and mediation and conflict resolutionba   business administration    whitti college city   statebusiness administrationpeter d veazey',
#  'and health teacher',
#  'associate of apply business administration human resource management study payroll record and accounting and business lawtrumbull business college city   state     human resource management study payroll record and accounting and business law',
#  'ba   sport and recreation management   may   new england college ï¼ city   state gpa graduate magna cum laudesport and recreation management graduate magna cum laude aa   liberal art   may   sussex county community college ï¼ city   state liberal artswork history',
#  'and traininghigh school diploma   jackson liberty high school   city   stateassociate of science   psychology university of south florida psychologyassociate of science   psychology temple university   city   state psychology',
#  'and trainingbusiness and computer science norwalk community college ï¼ city   state',
#  'africana studies university of arizona ï¼ city   state   usa attend august    may kineciology and wellness pasadena city college ï¼ city   state   usa attend august   present',
#  'and trainingchief sealth international high school   city   state high school diploma',
#  'bachelor   art human resource management    saint leo university ï¼ city   state',
#  'university of nebraska   lincoln master of science   marriage and family therapy marriage and family therapyuniversity of nebraska   lincoln bachelor of science   human development human development',
#  'and traininggraduate   western high school city   statetallahassee community college city   state',
#  'master of science   sport management   coach   sport administration    american public university ï¼ city   statecurrently enrol in online program for graduate schoolcoursework coaching theory   leadership event management sport finance sport lawbachelor of science   fitness   human performance   exercise science    university of houston clear lake ï¼ city   statecoursework exercise physiology kinesiology sport medicine health promotion nutrition first aidtransfer   general    san jacinto college north ï¼ city   statetransfer studentstudentathlete basketballhigh school diploma   general    la marque high school ï¼ city   stateawarde full athletic scholarship   san jacinto collegefinishe top   of class   national honor societymember of pal peer assistance leadership program   fca fellowship of christian athlete',
#  'associate of science   nursing collin county community college nursingcoursework in human anatomy and physiology certify nutritionist attend sport nutrition seminar certify weight managementconsultant cooper institute of dallaspersonal information   us    we',
#  'and trainingcity university of seattle   bachelor of art   management city   state gpa gpa managementfort sam houston military academy of science   city   state gpa gpa',
#  'bachelor of science   criminal justice   kaplan university citycriminal justiceassociate of art   early chilhood june   oakton community college city   stateassociate art in teach early childhoodhigh school diploma june   evanston township hs city   state',
#  'and certificate troubleshoot q comptia a certify   q advanced troubleshooting q comptia net certification class qvirus and spyware removal q mcsa certification class q computer diagnostic and repair q web development I   ii class q gaming consolerepair and q digital medium manipulation class modification q java programming class q mobile device repair q hardware support andprogramming and web troubleshooting q html   html q optimizing and performance tune q xml q audio and video technology qcss   css q medical technology installation and q javascript troubleshoot q command line q java management q actionscript qhardware and software upgrade q php plan q database server q documentation q android mobile application q organizationdevelopment q multiproject priority management q content management system cms operating system q website enhancement qwindow     q storyboarde q window server     q search engine optimization seo q window phone     q socialmedia and marketing q multiple linux distribution q ubuntu   lts    network q android     q cloud computing q macos x v   v q server management q io     q active directory q remote connection technology program q proficiency innumerous protocol q microsoft office   include tcpip q small business management q information security software client and serverq wireless technology q adobe creative suite   q telephony technology q wiring and network engineering graphic and medium q photoenhancing electronic q brochure and newsletter format q electronic circuit and component q audio and video editing q circuit diagramsand prototype q logo and business card q logic electronic and computational algorithm q electromagnetism and wave q quantum particlemechanic q as well as many miscellaneous it q energy and electrical alternative skill solar',
#  'master of science   leadership walden university ï¼ city   statemaster of science   information system management project management walden university ï¼ city   statebachelor of science   information system management mechanical engineering walden university ï¼ city   state',
#  'and train curry college city   state business management bachelor of art business management',
#  'none',
#  'ms   public administration government law sul ross university ï¼ city   state public administration government lawb   psychology education morgan state university ï¼ city   state psychology educationjunspecialize training _ security   certify ce augcyber   advance continue education course sepbasic computer operation planner course sepdisa action officer course dec dod information assurance boot camp nov computer network defensecomputernetwork threat',
#  'ms   electrical and computer engineering   dec   purdue university gpa gpa   electrical and computer engineering gpab   electrical and computer engineering   dec   gpa gpa   electrical and computer engineering gpa   thesis the designand evaluation of a   ghz laptopbase radar system publication â innovative laptop radar design to operate in both fmcw and cwmode â doppler shift dti range rti and sar measurement capability â operate in ism frequency band with dbm transmittingpower â datum acquisition and signal processing use matlab',
#  'computer technician    to',
#  'bachelor of science   information technology   florida international univeristy ï¼ city   state   united statescoursework in programming web administration network administration database administration and system administration âlinuxprogramming language c java jsp html css vbnet bash tsql',
#  'mba pepperdine universitybs   biology computer science loyola marymount university biology computer sciencenumerous class in project management and virtually all facet of it system',
#  'indiana university master   computer science indiana university   bloomington master in computer science august    december current gpa jawaharlal nehru technological university bachelor of technology   computer science and engineering jawaharlal nehru technologicaluniversity andhra pradesh india bachelor of technology in computer science and engineering september    may',
#  'master of business administration mba keller graduate school of management ï¼ city   statebachelor of science   telecommunication management devry university ï¼ city   state',
#  'department locate on the main campuschico center orland paradise and glenn countyrecommende modification or improvement for method procedure technique and equipment require for the business educationdegree program and computer lab result in time and cost saving for the departmentdesigne and maintain database of   year of graduate student follow their degree program and certificatesprovide effective instruction and tutoring to a widely diverse group of student in the follow career program microsoft office wordexcel access powerpoint and publisher computer application office assistant medical front office assistant legal officeassistant desktop publishing and medical transcription for certificationcollaborate with the technical support team to recommend new hardware and software to improve the performance of the computersmaintaine and update butte college business education websiteprovide desktop publish design work include creation of flyer brochure news release and newspaper ad outline special eventsand course offeringsassist enterprise network department by instal lab computer system   labs    system   new system validate lab systemimage every semester troubleshoot user hardware and software issue hardware repair memory upgrade software install os andsoftware patch installation and os upgrade to instructional support asst I',
#  'master of science   computer   information science    university of houston ï¼ city   state   usatop    of classemphasis in cyber security andâ information awarenessâ coursework in operating system and system programmingcoursework in computer networking and information technology bachelor of science   management of information system    university of maryland university college ï¼ city   state   usacoursework in computer networking and information technologyâ   gpa',
#  'certify associate in project management capm â   expire   expect in    master of science   information technology management    western governor university   city   state bachelor of science   business administration and management marketing and management international business    university of south carolina   columbia   state',
#  'bs   computer system engineer   january    fundacion universidad autonoma de colombia ï¼ city   colombia computer systemengineercomputer technician   april   certification in lan network administration   january   centro colombiano de estudio profesionale pontificia universidad javeriana ï¼city   colombia',
#  'knowledgesoft inc mechanicsburg pa   course in intranetware   administration and a advanced administration   shippensburg university of pennsylvania city   statebsba   business administrationoffice administration    john l grove college of business business administrationofficeadministrationbusiness communication business programming marketing finance ibm software application and managementaa    harrisburg area community college city   state gpa gpa   accounting ibm software application intermediate lotus advanced lotus   macros msdo command ibm basic programming advanced wordperfect   and novell netware gpa academicsbusiness    east pennsboro area high school city   state academicsbusiness type word process office proceduresbookkeeping and shorthand recipient of award for east pennsboro most outstanding business student',
#  'bachelor of science bs   information technology    university of phoenix gpa gpa   information technology gpa associate of apply science aas   electronic technology    cochise college gpa gpa   phi theta kappa electronic technologygpa   phi theta kappaassociate   general study    ag cochise college gpa gpa   phi theta kappa general studies gpa   phi theta kappa',
#  'comp a course window   course comptia network course comptia security course window server   class ccna classcertifie ethical hacker class comptia network certification comptia security certification comptia a certification mcse microsoft certify professional system engineer   ccna cisco certify network associate    northern virginia communitycollege virginia commonwealth university gpa deans list gpa   dean list gpa ma   education biology and general science    george mason university fairfax city education biology and general sciencebs   biology    biologynvcc alexandria aas networking   nvcc alexandria aas microcomputer specialization   virginiacommonwealth university richmond',
#  'master of science   computer information system   murray state university city   state project management and datum analysis emphasismaster of art   education   murray state university city   state educational technology emphasisbachelor of science   education   murray state university city   statemiddle school science and social study emphasisgpa information technology certificationscomptia   strata it fundamentalsmicrosoft technology associate   network fundamentalsmicrosoft technology associate â window os fundamentalsmicrosoft technology associate   software developmentâ microsoft technology associate   web development',
#  'bachelor of science   management information system cardinal stritch university city   stateonline profilelinkedinwwwlinkedincominrobertrjordan â',
#  'master of business administration mba   management information system general delta mu delta suffolk university   sawyer school ofmanagement city management information system general delta mu deltabachelor of art ba   economics gpa omicron delta epsilon economics omicron delta epsilon',
#  'program report to lead supervisor of disa naval service desk supportindependently manage and file data tape entry into appropriate storage drivesconsistently receive excellent evaluation on reviewseducation and courseworkshippensburg university city   state   usa organizational development and leadership odl master of scienceconcentration public organizationsrelevant coursesapplie organizational leadership and analysisethic for public service managersleadership charge and innovationleadership theory and practicepolicy implementation and administrationpublic policy analysisorganizational theory and behaviorresearch methodsyti career technical instituation city   state   usa network and internet security administration nisa associate technicalrelevant area of studyapplicationscomputer hardware and technologyoperate system and provisioningvirtual machinessecurity and system hardeningnetwork configurationsbackup imaging and disaster recoverymillersville university city   state   usa sociology bachelor of art',
#  'master of science   management project management colorado technical university gpa gpa coursework in business management and communicationsmanagement project management gpa bachelor of science   information technology university of phoenix gpa gpa coursework in distribute computing network and databasesinformation technology gpa',
#  'family financial planning graduate certificate   iowa state university   city   state will be a certify financial planner after completion     gpa gpa     gpa    bs   marketing   iowa state university   city   state marketingmicrosoft front page certify new horizon   des moine ia a ccomplishment     l roll out the first company wide intranet for a fortune   company l learn two computer language on my own to well understand thelimit of what developer can do l in   elect professional and scientific representative l implement entire electronic thesisdissertationsolution at iowa state university l publish paper at international academy of technology education and development iate conferenceempowere department across the university by use web technology â',
# ...
#  'university of louisville city   state   united states bachelor of science   double major in political sciencehistoryattende the university of louisville on full academic scholarshipcurrently enrol towards a degree in organizational leadership   learn with a specialty in leadingtrainingplan on move to mbahr degree after graduationmilitary experiencemay tomarch',
#  'none',
#  'high school diploma   oak hill high school   city   state gpa top   of class graduate with honor member of national honorsociety treasurer of fcclatop   of classgraduate with honorsmember of national honor societytreasurer of fcclaskillsâ cash management communication skill computer literatecustomer service',
#  'and trainingmay high school diploma madill high school ï¼ city   state graduate in the top   of my class captain of our drill team president of the highschool show choirjan elementary education ardmore high education center ï¼ city   state elementary education   unfortunately do not receive a degree iwithdrew from class to take care of my grandmotherwork history',
#  'high school diploma   general    ardmore high school   city   state   usa gpa gpa   general member of football and basketballteams gpa   university center of southern oklahoma   ardmore ok usacomplete on semester at this universityprairie view be university prairie view tx usacomplete one semester at this universityuniversity of central oklahoma gpa gpa   edmond ok usacomplete one full year at this university gpa',
#  'may   high school diploma   general business ringgold high school city   state monitor checkout station to ensure that they haveadequate cash available and that they be staff appropriately maintain clean and orderly checkout area and complete other general cleaningdutie such as mop floor and empty trash can automatic debit issue receipt refund credit or change due to customer assistcustomer by provide information and resolve their complaint establish or identify price of good service or admission and tabulate billsuse calculator cash register or optical price scanner greet customer enteringestablishment answer customer question and provideinformation on procedure or policy sell ticket and other item to customer process merchandise return and exchange assist with duty inother area of the store such as monitor fitting room or bag and carry out customer item sort count and wrap currency and coinssupervise other and provide onthejob training stock shelf and mark price on shelf and item bag box wrap or giftwrap merchandiseand prepare package for shipment post charge against guest or patient account keep periodic balance sheet of amount and number oftransaction count money in cash drawer at the beginning of shift to ensure that amount be correct and that there be adequate changecalculate total payment receive during a time period and reconcile this with total sale compute and record total of transaction compile andmaintain nonmonetary report and record',
#  'diploma   graphic design    lansdale school of business ï¼ city   state   usgraphic designassociate degree   office operation management    lansdale school of businessoffice operation managementpennsylvania real estate license    schlicker kratz re institute licensed',
#  'and trainingcentury business college city   state   united states business management',
#  'ge   san francisco state   city   state business marketing business communication and organizational psychologybachelor degree   business marketing business communication and organizational psychology san francisco state   city state business marketing business communication and organizational psychologycoursework in marketing and advertising business development training communication   relationship psychology interpersonal communication american river college   city   state coursework in communication contract law and environmental and geographical sciencesâ elect captain of   women water polo teamelecte captain of   women swim teamcommunication   communications american river college   city   state coursework in communication contract law and environmental and geographical sciencesâ elect captain of   women water polo teamelecte captain of   women swim team',
#  'high school diploma june   charles churn christian academy',
#  'high school diploma somerville high school ï¼ city   stateassociate of art   math and science somerset county collete ï¼ city   state math and sciencebachelor of art   broadcast communication geneva college ï¼ city   state broadcast communication',
#  'high school diploma manchester central high school ï¼ city   statesociology and justice studies university of new hampshire ï¼ city   state sociology and justice study',
#  'mba university of arkansas city   statebs   business administrationmarkete university of central arkansas city   state business administrationmarketinghigh school diploma mansfield high school city   state',
#  'high school diploma   prospect mountain high school city   state member of history club winter carnival planning committee cofounder of mr and mrs prospect mountain charity competition   expand function dental assistant certificate dental assistantdental assist   new hampshire technical institute city   state',
#  'and trainingphd   management information system walden universtiy city   statemba   business administration   webster university city   statebachelor of science   public relation   university of florida city   state',
#  'and trainingbs   business administration management   marketing option   may   the pennsylvania state university business administrationmanagement   marketing option   dean list master of professional study in data analytic â business analytic option    the pennsylvania state university ï¼ city   statemaster of professional study   datum analytic   business analytic option   present the pennsylvania state university datum analytic   businessanalytic option marketing assistant   october   icap indian cultural association of pennsylvania ï¼ city   state marketing assistant complete eventplanne by analyze budgetary constraint gain communication and relationship building skill while interact with member during event setupsmarket event through social medium while market the brand through selfbrande',
#  'select one   human resource   may   defense equal opportunity institute ï¼ city   state   usathe alternative dispute resolution mediator course at deomi patrick air force basebachelor of business administration   international business    university of the incarnate word ï¼ city   state   usagraduated with a   gpadeans list fall human resource    university of pennsylvania ï¼ city   state   usamaster resiliency trainer course level I   university of pennsylvania',
#  'master of science   counseling psychology georgia school of professional psychology   city   statecounsele psychology intern my sister house atlanta union missionvolunteer atlanta regional psychiatric hospitalbachelor of science   psychology radford university   city   state   usapsychiatric intern volunteer st albans psychiatric hospitalcoursework in marketing',
#  'none',
#  'bba   accounting university of texas of the permian basin ï¼ city   state   united states account',
#  'none',
#  'none',
#  'high school diploma may   coastal carolina university city   statemarine scienceshigh school diploma trinity high school city   state',
#  'medical transcription   athomeprofession city   usaassociate of art   st gregorys college city   state   usaexecutive secretary oklahoma state university city   state   usa',
#  'associate of art   current miami dade college   city   state gpamember of the supernatural movementâ clubcoursework in accounting finance and statisticshigh school diploma    miami senior high school   city   state',
#  'and trainingmorgan state university earl g grave school of business   city bs in hospitality   business management complete coursework in finance accounting and marketingthe curriculum emphasize managerial leadership and be design to developprepare student with theoretical and apply business andhospitality knowledge skill value and attributessoftball team',
#  'ge   general education study   del sol high school   city   stategeneral education study',
#  'high school diploma   current washtenaw technical middle college   city   state special program where I finish my last two year of highschool and get my associate degree at the the same time',
#  'bachelor of arts   georgia state universityanthropolgy atlanta ga usaprehistorichistoric culturally significant coursework and field study and excavation â under the late dr roy s dicken',
#  'and trainingbuckingham county high school city   state   usa high school diploma   business',
#  'master of business administration   marketing   project management southern new hampshire universitybachelor of art   history   political science management   marketing manhattanville collegepmp certificate in project management certificate in digital plate processing certificate in prepress preparation   processing certificate in softproofe certificate in    color processing   correction certificate in social medium advertising certificate in email marketing certificate inseo search engine optimization certificate in google analytic search advertising certificate in brand   fan building certificate in dprinte workshop certificate in digital photography workshop',
#  'educate patient about medical procedure step recovery measure and medication instructionsphysician supportconsistently praise by physician for efficient assistance in minor surgical procedure and patient handlingsurgical preparationprepare patient for surgery by perform screening test evaluate vital and administer proper medication collaborationcompliancefamily supporteducate family about procedure treatment regimen prevention and caremaintaine compliance with regulatory standard by compliance activity collaborate with physician to plan and implement patient care',
#  'plantation high school city   state   usa graduate in august of',
#  'high school diploma wingo high shool ï¼ city   state   usa',
#  'state license   real estate sale    austin institute of real estate ï¼ city   statebusiness building marketing and real estate salesgeneral education communication purdue university ï¼ city   stategeneral education communicationscommunication market long beach city college ï¼ city   statecommunication marketing',
#  'high school diploma   general education   national university academy   city   state general educationriverside city college   city   state',
#  'medium production not yet graduate    the art institute of ft lauderdale ï¼ city   statehigh school diploma    coconut creek high school ï¼ city   stateacademic high school graduate',
#  'high school diploma lugoff elgin high school ï¼ city   state',
#  'and traininghigh school diploma oak creek high school ï¼ city   statetelephone   high school diploma oak creek high school ï¼ city   statetelephone   high school diploma oak creek high school ï¼ city   statetelephone   high school diploma oak creek high school ï¼ city   statetelephone  ',
#  'june   downer grove north high school   some college',
#  'jun   high school diploma   quest academy city   state associate of art   chabot college   political science city   statelan gu age',
#  'and trainingassociate of art mar   tint school of makeup   cosmetology grand ï¼ city   state nail technicianhigh school diploma jul   moises e molina high school ï¼ city   state',
#  'nursing   university of mobile city   state   usai attend university of mobile program for center for adult program and professional study nursingbachelor of science   leadership   cultural study   university of mobile city   state   usai have a degree in leadership   cultural study with a minor in international business all   year of college I make the dean list and graduatedwith a   gpa my degree include study in philosophy world politic religion and ethic emphasize communication critical thinking andinterpersonal relation skill it be design to build skill necessary for position in human resource management counseling and other serviceoriente position the bachelor of science in leadership and cultural study develop proficiency in communication critical thinking andinterpersonal relation the emphasis in communication include composition the art logic and counsel critical thinking involve study inphilosophy world politic and religion as well as ethic and psychology interpersonal preparation add consideration of world conflict and itsresolution and investigation into tradition of leadership',
#  'and traininghigh school diploma   edmond north high school city   statebusinessmarketing   oklahoma christian university city   statebusinessmarketing   harding university city   state',
#  'and trainingdec high school diploma derby high school ï¼ city   stateseptember eric fisher academy ï¼ city   state',
#  'arizona state university   bachelor of art   african american studies city   state   united states present arizona state university',
#  'diploma stone mountain high ï¼ city   statecertificate georgia medical ï¼ city   state',
#  'high school diploma   generalbusiness study   miami coral park ï¼ city   state   we   graduate with high school diploma generalbusiness studies miami coral park srn high   miami fl',
#  'high school high school diploma   john jay',
#  'bachelor of science   business administration    the citadel the military college of south carolina ï¼ city   state   us bachelor ofscience business administration    the citadel the military college of south carolina charleston south carolinapresentationsprospect new customer and call on exist client account provide informative presentation on all product show catalog makerecommendation quote and negotiate pricespayment term submit proposal secure purchase order agreement and initiate additional salesthrough telemarketing',
#  'as   network engineering   moorpark college network engineeringa   computer information system   moorpark college computer information systems simi valley high school graduate',
#  'business administration pace university ï¼ city   statehigh school diploma   marketing murry bergtraum hs for business career ï¼ city   state   usa',
#  'and trainingbachelor of science   mechanical engineering lehigh university mechanical engineering',
#  'may bachelor of science   fashion merchandising management fashion institute of technology state university of new york fashion merchandisingmanagement',
#  'and training associate of science   computer engineering technology edutec   city automotive mechanic mechtech collage   city',
#  'bachelor of art   religion psychology   charleston southern university city   state',
#  '  general education santa rosa junior college ï¼ city   statebachelor   fine art academy of art university ï¼ city   statefine art',
#  'castleberry city   state   usa ge   generalgeneralcastleberry   river oak texas usa I also have commercial driver training heavy equipment operator certificate forklift operatorcertificate operation and quality management coursework I also have a certificate for attend a alcohol and drug behavioral awarenessclass as well as a cpr and firstaid class',
#  'master of science   international marketing   hult international business school   city   state   united states of americagenerate one year business and marketing plan for edmundscom with complete support of the companycreate a one year business and advertising plan for nbc tv interact with the company dailymaster of science   marketing   iede business school   city   state   chilebachelor of science   business and management administration   andre bello national university   city   state   chile',
#  'and traininghigh school diploma stevens high school ï¼ city   state   usabusiness management black hill state university ï¼ city   state   usa',
#  'bookkeepe   stratford career institute ï¼ city   state   canada the training source inc',
#  ...]

# %% [markdown]
# **Creating a List of CVs from the Extracted Information**

# %%
cvs_list = []
for i in range(len(pdf_path)):
  cvs_list.append(category_preprocessed[i]+" "+skills_preprocessed[i]+" "+education_preprocessed[i])

# %%
cvs_list
# Out:
#  'directorpresident   minturn fitness center highlevel strategic alliance skill include but not limit to network collaboration sponsorship and partnership for sscv presentdirector of facility and operation minturn fitness center presentnote accomplishmentswomen fis team coach for sscv produce the most athlete from a single program to make the usst during the   year span usst disabledparalympic alpine coach of the year design and execute firstever dedicated sscv strength and conditioning program design and execute firstever hour continue education program for ski and snowboard club vail full and parttime athleticstaff   staff member direct allinclusive human performance program for sscv include strength and conditioning sport psychology nutrition andmedical intervention presentpropose design build and provide operational oversight of all facet of the minturn fitness center on the vssa campus includingoperation hire membership management marketing and advertising programming for general population junior highschool andelitevip athlete present at the nfl combine in indianapolis i d on the subject of power training for olympic success spring',
#  'general manager budget conflict resolution cpr customer service delivery employee training first aid form health promotion hr leadership bs   kinesiology    university of montevallo ï¼ city   state kinesiology complete numerous course in sport health and fitness withconcentration in health promotionfirst aidcpraed certify',
#  'sale associate excellence and experience in customer service eager and fast learner honest advanced problemsolve exceptional organizational skill associate of art   general business mesa community college ï¼ city   state general business currently attendinghigh school diploma james madison preparatory school ï¼ city   state',
#  'director of operation account management account receivables administrative support subordinate counseling computer proficiency customer service bachelor of science   healthcare administration    southwestern college ï¼ city   state gpa summa cum laude graduatehealthcare administration summa cum laude graduateassociate of apply science   leadership and management    us air force air university distance learningtraining specialize in leadership management managerial communication total quality management management theory management byobjective motivation counseling and diversityassociate of apply science   fitness recreation and service management    community college of the air force fitness recreationand service managementskillsaccount management account receivables administrative support subordinate counseling computer proficiency customer servicefinancial report reconcile fund management inventory logistic director risk management secretarial duty communication skill totalquality management executive management support file grammar internet research letter and memo lotus note microsoft excelmicrosoft office suite microsoft outlook microsoft powerpoint microsoft word minute take multitask management organizational',
#  'senior sale management consultant work history bs   business administration    northern arizona university   city',
#  'cashier account administrative support benefit bill clerical counseling clientele client client customer service datum entry database none',
#  'certify personal trainer and group fitness instructor accounting budget business management competitive content contract course development client client database management database master of science   communication   medium management    virginia commonwealth university ï¼ city   state   usa communication medium management concentration communication marketing and public relation coursework in business management with a focus on medium',
#  'general managerfitness director microsoft windows microsoft powerpoint microsoft outlook microsoft access skill bs   holistic nutrition    clayton college of natural health holistic nutritionaccounting   management human resource    california state university accounting   management human resourcesskillsmicrosoft windows microsoft powerpoint microsoft outlook microsoft access skill internet explorer and social medium',
#  'general manager outstanding leadership bachelor of science   sport and leisure study the ohio state university',
#  'cashier cash handling and trainingfitness nutrition certification   personal training certification   nutrition science human anatomy and physiology weight loss management national academy of sport medicine city   statecoursework in health and physical educationexercise science and kinesiologypersonal trainer certificateattende seminar on weight loss managementcoursework in nutrition science human anatomy and physiologybachelor of science   nutrition science human anatomy and physiology clark atlanta university city   statecoursework in nutrition sciencehuman anatomy and physiologymember of biological science club gpa',
#  'branch manager skill use bachelor of science   criminal justice anthropology    the state university of new jersey ï¼ city   state   united statesgpa',
#  'fitness director skill use high school diploma   general education    camden county high school ï¼ city   state general educationwilling to relocate anywhere',
#  'personal trainer group fitness instructor microsoft office powerpoint presentation skill social medium branding ms   kinesiology    university of texas el paso ï¼ city   state   usgpa   teacher assistant for undergraduate and graduate class',
#  'wellness director skill bachelor of science   natural health study    clayton college of natural health   city   state work historywellness director    to current',
# ...
#  'sale associate advertisement calculator cash register competitive credit client customer relation customer service database email issue receipt high school diploma june   charles churn christian academy',
#  'sale blueprint read blueprint interpersonal   communication conference customer relation excellent customer service direction hire layout high school diploma somerville high school ï¼ city   stateassociate of art   math and science somerset county collete ï¼ city   state math and sciencebachelor of art   broadcast communication geneva college ï¼ city   state broadcast communication',
#  'sale associate great communication skill excellent customer service customer service experience customer service fast focus inventory control multi high school diploma manchester central high school ï¼ city   statesociology and justice studies university of new hampshire ï¼ city   state sociology and justice study',
#  'sale manager territory sale manager advertising book excellent communication computer knowledge contract client documentation innovation inventory team build mba university of arkansas city   statebs   business administrationmarkete university of central arkansas city   state business administrationmarketinghigh school diploma mansfield high school city   state',
#  'sale associate professional and friendlyâ high school diploma   prospect mountain high school city   state member of history club winter carnival planning committee cofounder of mr and mrs prospect mountain charity competition   expand function dental assistant certificate dental assistantdental assist   new hampshire technical institute city   state',
#  'sale associate billing billing system budget budget business management coldcalle client customer service datum analysis database facility maintenance and trainingphd   management information system walden universtiy city   statemba   business administration   webster university city   statebachelor of science   public relation   university of florida city   state',
#  'sale engineer strong analytical skill and trainingbs   business administration management   marketing option   may   the pennsylvania state university business administrationmanagement   marketing option   dean list master of professional study in data analytic â business analytic option    the pennsylvania state university ï¼ city   statemaster of professional study   datum analytic   business analytic option   present the pennsylvania state university datum analytic   businessanalytic option marketing assistant   october   icap indian cultural association of pennsylvania ï¼ city   state marketing assistant complete eventplanne by analyze budgetary constraint gain communication and relationship building skill while interact with member during event setupsmarket event through social medium while market the brand through selfbrande',
#  'sale associategolf sale associate highly effective leader in extreme situation as well as normal condition posse the ability to place the correct personnel with the appropriate select one   human resource   may   defense equal opportunity institute ï¼ city   state   usathe alternative dispute resolution mediator course at deomi patrick air force basebachelor of business administration   international business    university of the incarnate word ï¼ city   state   usagraduated with a   gpadeans list fall human resource    university of pennsylvania ï¼ city   state   usamaster resiliency trainer course level I   university of pennsylvania',
#  'sale associate lee green associate master of science   counseling psychology georgia school of professional psychology   city   statecounsele psychology intern my sister house atlanta union missionvolunteer atlanta regional psychiatric hospitalbachelor of science   psychology radford university   city   state   usapsychiatric intern volunteer st albans psychiatric hospitalcoursework in marketing',
#  'db sale skill none',
#  'sale account receivable adp closing cold bba   accounting university of texas of the permian basin ï¼ city   state   united states account',
#  'outbound sale pricing sale inbound and outbound audit documentation filing inspection maintenance medical record basis receptionist customer none',
#  'pmcpsm sale manager sale associate ability to clarify the nature of a problem evaluate alternative propose none',
#  'sale associate advertise cash register color cooking critical thinking customer service decision make english maintain inventory inventory listen high school diploma may   coastal carolina university city   statemarine scienceshigh school diploma trinity high school city   state',
#  'sale associate none medical transcription   athomeprofession city   usaassociate of art   st gregorys college city   state   usaexecutive secretary oklahoma state university city   state   usa',
#  'sale trust key holder associate of art   current miami dade college   city   state gpamember of the supernatural movementâ clubcoursework in accounting finance and statisticshigh school diploma    miami senior high school   city   state',
#  'sale self starter and traininghigh school diploma   edmond north high school city   statebusinessmarketing   oklahoma christian university city   statebusinessmarketing   harding university city   state',
#  'sale associate teamwork and trainingdec high school diploma derby high school ï¼ city   stateseptember eric fisher academy ï¼ city   state',
#  'sale associate customer service retail sale associate cashierm exceloffice powerpoint word arizona state university   bachelor of art   african american studies city   state   united states present arizona state university',
#  'sale clerk osha inspection diploma stone mountain high ï¼ city   statecertificate georgia medical ï¼ city   state',
#  'sale sale telephone inventory point of sale credit cash customer service receptionist retail sale answer associate client exceed high school diploma   generalbusiness study   miami coral park ï¼ city   state   we   graduate with high school diploma generalbusiness studies miami coral park srn high   miami fl',
#  'sale consultant career overview high school high school diploma   john jay',
#  'sale sale sale representative in sale corporate sale operation sale and account and account for and sale billing business bachelor of science   business administration    the citadel the military college of south carolina ï¼ city   state   us bachelor ofscience business administration    the citadel the military college of south carolina charleston south carolinapresentationsprospect new customer and call on exist client account provide informative presentation on all product show catalog makerecommendation quote and negotiate pricespayment term submit proposal secure purchase order agreement and initiate additional salesthrough telemarketing',
#  'sale associate adobe cable hardware copy customer service datum entry direction fax ie inventory loss prevention mail win monitor pc as   network engineering   moorpark college network engineeringa   computer information system   moorpark college computer information systems simi valley high school graduate',
#  'timeshare sale sale sale management staff workflow account management accounting administrative support business plan consultation business administration pace university ï¼ city   statehigh school diploma   marketing murry bergtraum hs for business career ï¼ city   state   usa',
#  'sale engineer extensive experience of plan project management and trainingbachelor of science   mechanical engineering lehigh university mechanical engineering',
#  'sale associate proficiency in microsoft office suite adobe creative suite ronlynn apparel software both mac and pc platform social medium include may bachelor of science   fashion merchandising management fashion institute of technology state university of new york fashion merchandisingmanagement',
#  'sale associate inventory control procedure and training associate of science   computer engineering technology edutec   city automotive mechanic mechtech collage   city',
#  'sale customer service bachelor of art   religion psychology   charleston southern university city   state',
#  'sale coordinator experience of   year in the field of design as an illustrator   general education santa rosa junior college ï¼ city   statebachelor   fine art academy of art university ï¼ city   statefine art',
#  'sale representative benefit billing competitive contract cpr client delivery dependable documentation driver equipment operator expense report first castleberry city   state   usa ge   generalgeneralcastleberry   river oak texas usa I also have commercial driver training heavy equipment operator certificate forklift operatorcertificate operation and quality management coursework I also have a certificate for attend a alcohol and drug behavioral awarenessclass as well as a cpr and firstaid class',
#  'sale manager office suite sql google product master of science   international marketing   hult international business school   city   state   united states of americagenerate one year business and marketing plan for edmundscom with complete support of the companycreate a one year business and advertising plan for nbc tv interact with the company dailymaster of science   marketing   iede business school   city   state   chilebachelor of science   business and management administration   andre bello national university   city   state   chile',
#  'sale associate motivate seller â   â   â   â   â   â   â   â   â   â   â   â   â   â   â â and traininghigh school diploma stevens high school ï¼ city   state   usabusiness management black hill state university ï¼ city   state   usa',
#  'sale associatemerchandiser account reconciliation administrative advertising benefit brochure communication skill contract creative problem solver credit client bookkeepe   stratford career institute ï¼ city   state   canada the training source inc',
#  ...]

# %% [markdown]
# # **Part 2 - Job Description Data Understanding**

# %% [markdown]
# **Importing Libraries**

# %%
import pandas as pd
import re
import string
import nltk
import spacy
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

# Download NLTK resources (if not already downloaded)
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")
nlp = spacy.load("en_core_web_sm")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# **Extract first 10 rows from the Dataset**

# %%
df = pd.read_csv('/content/drive/MyDrive/job_description.csv')
df = df.head(10)
display(df)
# Out:
#                               company_name  \
# 0                                   Google
# 1                                    Apple
# 2                                  Netflix
# 3                              Robert Half
# 4                                TrackFive
# 5                                DesignUps
# 6                          Equisolve, Inc.
# 7                  Zander Insurance Agency
# 8                                     Tuff
# 9  General Dynamics Information Technology
#
#                                      job_description  \
# 0  minimum qualifications\nbachelors degree or eq...
# 1  description\nas an asc you will be highly infl...
# 2  its an amazing time to be joining netflix as w...
# 3  description\n\nweb designers looking to expand...
# 4  at trackfive weve got big goals were on a miss...
# 5  designups is a nashville based design and inte...
# 6  about the position\n\nthe web designer is resp...
# 7  job description\n\nzander insurance group is o...
# 8  tuff is a growth marketing team working with c...
# 9  type of requisition regular\n\nclearance level...
#
#                               position_title  description_length  \
# 0                           Sales Specialist                2727
# 1                 Apple Solutions Consultant                 828
# 2  Licensing Coordinator - Consumer Products                3205
# 3                               Web Designer                2489
# 4                              Web Developer                3167
# 5                     Frontend Web Developer                 892
# 6                    Remote Website Designer                3471
# 7                               Web Designer                2896
# 8                               Web Designer                5143
# 9                           SR. Web Designer                4023
#
#                                       model_response
# 0   {\n  "Core Responsibilities": "Responsible fo...
# 1   {\n  "Core Responsibilities": "as an asc you ...
# 2   {\n  "Core Responsibilities": "Help drive bus...
# 3   {\n  "Core Responsibilities": "Designing webs...
# 4   {\n  "Core Responsibilities": "Build and layo...
# 5   {\n  "Core Responsibilities": "Translate desi...
# 6   {\n  "Core Responsibilities": "Provide design...
# 7   {\n  "Core Responsibilities": "Design compell...
# 8   {\n  "Core Responsibilities": "Work on variou...
# 9   {\n  "Core Responsibilities": "Designs and bu...

# %% [markdown]
# **Extract columns 'position_title' and 'job_description' into lists and preprocess them**

# %%
position_title = df['position_title'].astype('str').to_list()
job_description = df['model_response'].astype('str').to_list()

# %%
job_description_list = []

for i in range(len(position_title)):
  job_description_list.append(position_title[i]+job_description[i])

# %%
job_description_preprocessed = []

def preprocess_text(text):
    # Remove URLs
    text = re.sub(r'http\S+', '', text)

    # Remove email addresses
    text = re.sub(r'\S+@\S+', '', text)

    # Remove special characters and digits
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub(r'\d+', '', text)

    # Convert text to lowercase
    text = text.lower()

    # Remove newline characters
    text = text.replace('\n', '')

    # Tokenize using SpaCy
    doc = nlp(text)
    tokens = [token.text for token in doc]

    # Remove stopwords using NLTK and SpaCy
    stopwords_nltk = set(nltk.corpus.stopwords.words("english"))
    stopwords_spacy = nlp.Defaults.stop_words
    tokens = [token for token in tokens if token not in stopwords_nltk]
    tokens = [token for token in tokens if token not in stopwords_spacy]

    # Perform stemming using NLTK
    stemmer = nltk.PorterStemmer()
    tokens = [stemmer.stem(token) for token in tokens]

    # Perform lemmatization using SpaCy
    tokens = [token.lemma_ for token in doc]

    # Join the preprocessed words back into a string
    preprocessed_text = " ".join(tokens)
    return preprocessed_text

# Example usage
for text in job_description_list:
  preprocessed_tokens = preprocess_text(text)
  job_description_preprocessed.append(preprocessed_tokens)

# %%
job_description_preprocessed
# Out:
# ['sale specialist    core responsibility responsible for expand google workspace product adoption across an assign territory build relationship with customer to understand need and provide google workspace solution partner with account team to construct solution and grow business for google workspace   require skill bachelor degree or equivalent experience experience manage enterprise saas account and sale cycle    educational requirement bachelor degree or equivalent experience   experience level experience manage enterprise saas account and sale cycle   prefer qualification experience build strategic partnership with enterprise customer ability to work through a reseller ecosystem excellent communication and strategic thinking skill   compensation and benefit na',
#  'apple solution consultant    core responsibility as an asc you will be highly influential in grow mind and market share of apple product while build longterm relationship with those who share your passion customer experience be drive through you and your partner team grow in an ever change and challenging environment you strive for perfection whether its maintain visual merchandising or help to grow and develop your partner team   require skill a passion to help people understand how apple product can enrich their livesexcellent communication skill allow you to be as comfortable in front of a small group as you be speak with individual year prefer work in a dynamic sale andor result drive environment as well as prove success develop customer loyaltyability to encourage a partner team and grow apple business   educational requirement na   experience level year prefer   preferred qualification na   compensation and benefit na',
#  'licensing coordinator   consumer product    core responsibility help drive business by support licensing manager on task relate to category management facilitate information between stakeholder maintain communication plan coordinate with internal team to share brand and marketing update with partner maintain and update title strategy and licensing plan collaborate with partner on product launch assist with licensing recap meeting and agreement   require skill   year experience in preferably outbound licensing understanding of category manufacturing and sale cycle for toysfoodbeverage prefer experience with entertainmentlifestyle brand selfstarter proactive flexible thrive under pressure superb organizational and multitaske skill excellent communication skill    educational requirement na   experience level   year experience in preferably outbound licensing   preferred qualification understanding of category manufacturing and sale cycle for toy andor food and beverage prefer experience work with reputable entertainment andor lifestyle brand   compensation and benefit na',
#  'web designer    core responsibility design website wireframe land page and mobile application implement design use html css and javascript qa testing site and application   require skill   year experience in web design proficiency with adobe creative cloud photoshop illustrator indesign strong html css javascript skill familiarity with content management system     educational requirement na   experience level   year   prefer qualification uxui design experience knowledge of brand standard and guideline   compensation and benefit na',
#  'web developer    core responsibility build and layout from provide psd file build dynamic web app use phpmysql framework leverage rest service and other thirdparty apis rapidly solve problemsbug and compatibility issue troubleshoot test and maintain the core product software and database   require skill   year of experience with html and csssass   year of experience with programming php application and lamp stack development experience with es javascript and jquery thorough understanding of relational database and security relate to phpmysql expert knowledge with content management system either from your own design or from mvc framework such as zend laravel etc ability to build and consume custom soap and rest apis   year of experience write unit test detail procedure selfmotivate require minimal supervision exceptional organization and communication skill   educational requirement na    experience level   year   prefer qualification na   compensation and benefit free health insurance for employee with no wait period dental and vision insurance trackfive split the cost pay birthday holiday companypaid short and longterm disability insurance companypaid life insurance flex time pay parental leave companymatche retirement plan with no waiting or vest period workfromhome option office perk like snacksmassagespet day opportunity to work with great people on exciting thing amazing holiday party',
#  'frontend web developer    core responsibility translate design responsively for multiple screen size work in wordpress frontend web development   require skill strong attention to design detail typography ui etc familiarity with bootstrap or similar framework wordpress knowledge    educational requirement na   experience level na   prefer qualification desire to learn wordpress   compensation and benefit na',
#  'remote website designer    core responsibility provide design support for client and internal website project collaborate with content and development team ensure highquality implementation of design use and evolve the design system   require skill   year experience in web or product design portfolio showcase typography interaction and visual design skill understanding of responsive design and modular design system figma and design tool proficiency strong communication skill selfstarter     educational requirement na   experience level   year experience as an individual contributor on a web or product design team   prefer qualification personal project display design aesthetic and passion ada and accessibility certification experience facilitate visual design adoption ability to communicate design decision   compensation and benefit remote work generous pto educationtraining allowance apple hardware insurance benefit companysponsore life insurance',
#  'web designer    core responsibility design compelling direct response website and digital content that support the brand campaign objective and drive measurable action utilize knowledge of company product and service to create effective design create design compatible across device create mockup and present idea to stakeholder continually improve user experience and drive revenue growth   require skill   year of digital design experience drive online sale or marketing ability to communicate effectively with highlevel client able to thrive in a fastpaced team environment open to new idea and able to adapt quickly proficiency with adobe creative suite include photoshop illustrator and indesign experience with sketch and ui wireframe ability to articulate design concept htmlcssjs experience prefer but not require     educational requirement na   experience level   year of relevant digital design experience   prefer qualification htmlcssjs experience   compensation and benefit competitive salary monthly profit distribution healthdental insurance pay   by company k match generous pay time off potential for remote work',
#  'web designer    core responsibility work on various website design and ongoing monthly improvement for   client this include testing cta remediate core page add land page refine pricing page update user flow redesign blog etc guide website project timeline scope and cost within the tuff process   require skill   year experience as a web designer experience with creative production tool like figma and adobe suite strong project management skill clean aesthetic and typography skill strategic thinker with passion for brand building and ux flexibility to work on multiple brand at once   educational requirement na   experience level   year experience as a web designer   prefer qualification experience work with creative production team learn mindset commit to continuous improvement bias toward action efficiency and adaptability success testing and uncover insight   compensation and benefit   salary range comprehensive health dental and vision coverage k with match unlimited pto parental leave home office stipend internet reimbursement annual team retreat',
#  'sr web designer    core responsibility design and build complex graphic page layout and animation for web page create detailed draft of website outline base on client need provide thorough testing and review of final website design   require skill proficiency in html css javascript drupal adobe photoshop illustrator after effect and lightroom    educational requirement bachelor degree or equivalent experience   experience level   year of experience   preferred qualification na   compensation and benefit na']

# %% [markdown]
# # **Part 3 - Candidate Job Matching**

# %% [markdown]
# **Importing Libraries**

# %%
import torch
from transformers import DistilBertTokenizer, DistilBertModel
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# Load the DistilBERT tokenizer and model
tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-uncased")
model = DistilBertModel.from_pretrained("distilbert-base-uncased")

# %% [markdown]
# **Create Embeddings for CVs and Job Descriptions**

# %%
# Create embeddings for each tokenized text
cv_embeddings = []

for text in cvs_list:
    # Tokenize and encode the text
    inputs = tokenizer(text, padding=True, truncation=True, return_tensors="pt")

    # Perform a forward pass through the model
    with torch.no_grad():
        outputs = model(**inputs)

    # Extract the embeddings (CLS token or average of all tokens)
    cls_embedding = outputs.last_hidden_state.mean(dim=1).numpy()[0]
    cv_embeddings.append(cls_embedding)

# Convert embeddings to a numpy array
cv_embeddings_array = np.array(cv_embeddings)

# # Now, 'embeddings_array' contains the embeddings for the tokenized text
# print(embeddings_array.shape)  # (number_of_text_samples, embedding_dimension)

# %%
# Create embeddings for each tokenized text
job_description_embeddings = []

for text in job_description_preprocessed:
    # Tokenize and encode the text
    inputs = tokenizer(text, padding=True, truncation=True, return_tensors="pt")

    # Perform a forward pass through the model
    with torch.no_grad():
        outputs = model(**inputs)

    # Extract the embeddings (CLS token or average of all tokens)
    cls_embedding = outputs.last_hidden_state.mean(dim=1).numpy()[0]
    job_description_embeddings.append(cls_embedding)

# Convert embeddings to a numpy array
job_description_embeddings_array = np.array(job_description_embeddings)

# # Now, 'embeddings_array' contains the embeddings for the tokenized text
# print(embeddings_array.shape)  # (number_of_text_samples, embedding_dimension)

# %% [markdown]
# **Find Cosine Similarity, Rank CVs based on it and show the Top 5 CVs for a given Job Description**

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# Assuming you have job_description_embeddings and cv_embeddings as NumPy arrays

# Choose a specific job description you want to compare against
chosen_job_description_idx = 4  # Replace with the index of the job description you want to compare

# Calculate cosine similarity between the chosen job description and all CVs
cosine_similarities = cosine_similarity(
    [job_description_embeddings_array[chosen_job_description_idx]], cv_embeddings_array
)

# Get the ranked indices of CVs based on similarity (descending order)
ranked_cv_indices = np.argsort(cosine_similarities[0])[::-1]

# Get the top 5 most similar CVs
top_5_cv_indices = ranked_cv_indices[:5]

# Print the top 5 CVs along with their cosine similarity scores
for i, cv_idx in enumerate(top_5_cv_indices, start=1):
    similarity_score = cosine_similarities[0][cv_idx]
    print(f"Top {i} CV (Similarity Score: {similarity_score}):")
    print(cvs_list[cv_idx])  # Assuming cv_data is a DataFrame with CV text
    print("\n")
# Out:
# Top 1 CV (Similarity Score: 0.9510120153427124):
# lead information technology support specialist application department locate on the main campuschico center orland paradise and glenn countyrecommende modification or improvement for method procedure technique and equipment require for the business educationdegree program and computer lab result in time and cost saving for the departmentdesigne and maintain database of   year of graduate student follow their degree program and certificatesprovide effective instruction and tutoring to a widely diverse group of student in the follow career program microsoft office wordexcel access powerpoint and publisher computer application office assistant medical front office assistant legal officeassistant desktop publishing and medical transcription for certificationcollaborate with the technical support team to recommend new hardware and software to improve the performance of the computersmaintaine and update butte college business education websiteprovide desktop publish design work include creation of flyer brochure news release and newspaper ad outline special eventsand course offeringsassist enterprise network department by instal lab computer system   labs    system   new system validate lab systemimage every semester troubleshoot user hardware and software issue hardware repair memory upgrade software install os andsoftware patch installation and os upgrade to instructional support asst I
#
#
# Top 2 CV (Similarity Score: 0.9484033584594727):
# assistant manager   hr sap r   ms office word excel power point outlook internet application have good understanding of sql html css and   training of staff and worker as per thetpm methodaudit responsible for face various customer audits like mm gm bajaj vw etc isot   emsohsa   tpmauditadministration management monitoring of canteen housekeeping security vehicle management stationery   guest managementhr initiative start various hr activity at the plant level like suggestion scheme coffee with hr connect to home skip level meetingknowledge share birthday celebration appreciation of employee establish cafeteria and libraryassistant manager   hr    to   company name to maintain hr databaseto generate various hr report require by the managementto maintain organizational structure create position and job in sap to provide support in the hr administration of pay and bonusreview provide report and stat to senior manager and support hrbps in the collation of workto maintain attendance and leave of employee in sapinvolve in the full life cycle of the recruitment process and on boardingprepare   update organizational chart   make head count as well as requirement report hr mispreparation of job description and role   responsibility of departmentresponsible for establishment implementation   maintain effective training   development system in the organizationstarte various hr activity at the plant level like suggestion scheme coffee with hr connect to home skip level meeting knowledgesharing birthday celebration appreciation of employee establish cafeteria and librarytimely distribution of performance appraisal form to all the departmentsinvolved in mid   review and yearly appraisal and delivery of appraisalpromotion letter on timeassistant manager   hr    to
#
#
# Top 3 CV (Similarity Score: 0.9480530023574829):
# patient access rep system software bachelor of science   computer information system telecommunication system support   tulane university city   state   usa associate of science   computer network engineering   delgado community college city   state   usa militaryunite states navy veteran honorable dischargetechnical skillssystem software adobe dreamweaver skill monitor daily production run for technical support ie disc backup database verificationsstatistic report perform complexity installation and maintenance of software skill in electronic medical record adobe flash help desksoftware html libm mainframes access excel microsoft office microsoft operating system powerpoint wordnetwork support instal and provide daytoday end user support of local area network by identify analyze testing and correctingprogram machine datum or procedural problem research test and document network lanwanenterprise operating system applicationsoftware product and peripheral hardware install software and hardware in order to manage monitor and support extensive computernetwork assist in monitor performance and efficiency of an enterprise network understand protocol tcpip active directorydatabase epic and ibm database programming skill documentation html website design train professional and user on thesystem document programming effort maintenance utility perform system programming support to run job and troubleshoot issue storagearea network skillscommunication skill excellent verbal and write communication skill with emphasis in customer support include experience handlingdifficult customer and conflict resolution excellent interpersonal skill and the ability to work collaboratively in team environment capable ofseee and manage project through from start to finish problemsolve skillscertification candidate project management professional pmp
#
#
# Top 4 CV (Similarity Score: 0.9472498297691345):
# director of community adobe creative suite microsoft office suite google app facebook twitter instagram pinterest tumblr google youtube blogger officefacilitate operation and communication with other office regard it finance security and hruse design experience writing and computer skill to market event and programsdesign promotional material for print and web as need such as postcard flier bannersmanage social medium page and design ad campaign leverage analyticsincrease social medium activity by   over past two yearsdesign and analyze email marketing campaignsresearch and coordinate with marketing staff to place web and print adsevent planning and management for community engagementprovide administrative support to a wide range of constituentsassist student with registration class preparation and communication while work toward enrollment goalsincrease enrollment by   through fresh marketing strategy and improve customer service policyassist faculty with design of course scheduling contract and facility and supply needscurate art class and workshop for triannual course catalog collect image bio and descriptionsproofread and edit catalog contentcoordinate bulk mailingmanage vendor and account relation for material and supply tracking and placing of ordersprocess tuition payment request and track refundsoversee scholarship programdevelop faculty pay scheduledraft collect and archive contractsassistant director november   to august
#
#
# Top 5 CV (Similarity Score: 0.9465948343276978):
# senior director information technology enterprise resource planning system groupstrengthene company business by lead implementation of industry lead sis for the management of the campus and crm foradmissionsnegotiate a new contract with vendor to reduce price by as much as develop and launch regular training session to help associate with most common report issue use domo to visualize trend insupport case and then develop training material on the most common report issuesinstitute a new web base support ticketing system which allow student faculty and staff member to generate ticket request for helpprior to this system only staff member could generate support ticket on an internal system the new system have rule incorporate which autoroute ticket base on the characteristic selectedrecommende and implement all of the enterprise application onto the cloud this save the organization   million amortize over   year ifwe be to have upgrade the infrastructure inhouse to accommodate the new enterprise applicationslaunche the migration of the staff and faculty to office   microsoft cloud version of office after migrate the student this enable everyuser to have access to the late version of the complete office suite and â onedrive for individual file storage from a system point of view theenterprise have access to the late version of system from microsoft plus an infinite access to microsoft resource to support the infrastructure to senior manager student information system
